# %% [markdown]
# # Introduction to Video Understanding

# %% [markdown]
# ## Instrucciones Generales
#
# El siguiente práctico se puede realizar de manera **individual**. El formato de entregar es el **archivo .ipynb con todas las celdas ejecutadas**. Todas las preguntas deben ser respondida en celdas de texto. No se aceptará el _output_ de una celda de código como respuesta.
#
# **Nombre:** Javier Rojas Benitez
#
# El siguiente práctico cuanta con 2 secciones donde cada una contendrá 1 o más actividades a realizar. Algunas actividades correspondrán a escribir código y otras a responder preguntas.
#
# **Importante.** Para facilitar su ejecución, cada sección puede ser ejecutada independientemente.
#
# Se recomienda **fuertemente** revisar las secciones donde se entrega código porque algunas actividades de código pueden reutilizar el mismo código pero con cambios en algunas líneas.

# %% [markdown]
# ## 1. Utilities

# %% [markdown]
# Essential libraries for executing this tutorial.

# %%
# !pip install imageio-ffmpeg
# Out:
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.13/dist-packages (0.6.0)

# %%
import os, cv2
from tqdm.notebook import tqdm
import re
import math
import numpy as np
import torch.utils.data as data
import random
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
import time
import copy
import matplotlib.pyplot as plt
import pandas as pd

from PIL import Image
import torchvision

# from tensorflow_docs.vis import embed
# from moviepy.editor import *

# %% [markdown]
# ## 2. Dataset

# %% [markdown]
# ### Download data

# %% [markdown]
# We will use the [UCF11 dataset](https://www.crcv.ucf.edu/data/UCF_YouTube_Action.php) consisting of YouTube videos containing 11 action categories. For this tutorial, the dataset is hosted in a repository that we own.

# %%
# !wget --no-check-certificate https://www.crcv.ucf.edu/data/UCF11_updated_mpg.rar
# Out:
# --2026-09-11 00:36:29--  https://www.crcv.ucf.edu/data/UCF11_updated_mpg.rar
# Resolving www.crcv.ucf.edu (www.crcv.ucf.edu)... 132.170.214.127
# Connecting to www.crcv.ucf.edu (www.crcv.ucf.edu)|132.170.214.127|:443... connected.
# WARNING: cannot verify www.crcv.ucf.edu's certificate, issued by ‘CN=InCommon RSA OV SSL CA 3,O=InCommon\\, LLC,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 1045106394 (997M) [application/x-rar-compressed]
# Saving to: ‘UCF11_updated_mpg.rar’
#
# UCF11_updated_mpg.r 100%[===================>] 996.69M  14.7MB/s    in 79s
#
# 2026-09-11 00:37:50 (12.5 MB/s) - ‘UCF11_updated_mpg.rar’ saved [1045106394/1045106394]

# %%
# !unrar x '/content/UCF11_updated_mpg.rar'
# Out:
# UNRAR 7.00 freeware      Copyright (c) 1993-2024 Alexander Roshal
#
#
# Extracting from /content/UCF11_updated_mpg.rar
#
# Creating    UCF11_updated_mpg                                         OK
# Creating    UCF11_updated_mpg/basketball                              OK
# Creating    UCF11_updated_mpg/basketball/v_shooting_01                OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_01/v_shooting_01_01.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_01/v_shooting_01_02.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_01/v_shooting_01_03.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_01/v_shooting_01_04.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_01/v_shooting_01_05.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_01/v_shooting_01_06.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_01/v_shooting_01_07.mpg     0  OK
# Creating    UCF11_updated_mpg/basketball/v_shooting_02                OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_02/v_shooting_02_01.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_02/v_shooting_02_02.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_02/v_shooting_02_03.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_02/v_shooting_02_04.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_02/v_shooting_02_05.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_02/v_shooting_02_06.mpg     0  OK
# Creating    UCF11_updated_mpg/basketball/v_shooting_03                OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_03/v_shooting_03_01.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_03/v_shooting_03_02.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_03/v_shooting_03_03.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_03/v_shooting_03_04.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_03/v_shooting_03_05.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_03/v_shooting_03_06.mpg     0  OK
# Creating    UCF11_updated_mpg/basketball/v_shooting_04                OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_04/v_shooting_04_01.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_04/v_shooting_04_02.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_04/v_shooting_04_03.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_04/v_shooting_04_04.mpg     0  OK
# Creating    UCF11_updated_mpg/basketball/v_shooting_05                OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_05/v_shooting_05_01.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_05/v_shooting_05_02.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_05/v_shooting_05_03.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_05/v_shooting_05_04.mpg     0  OK
# Creating    UCF11_updated_mpg/basketball/v_shooting_06                OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_06/v_shooting_06_01.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_06/v_shooting_06_02.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_06/v_shooting_06_03.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_06/v_shooting_06_04.mpg     0  OK
# Creating    UCF11_updated_mpg/basketball/v_shooting_07                OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_07/v_shooting_07_01.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_07/v_shooting_07_02.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_07/v_shooting_07_03.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_07/v_shooting_07_04.mpg     0  OK
# Creating    UCF11_updated_mpg/basketball/v_shooting_08                OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_08/v_shooting_08_01.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_08/v_shooting_08_02.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_08/v_shooting_08_03.mpg     0  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_08/v_shooting_08_04.mpg       1  OK
# Creating    UCF11_updated_mpg/basketball/v_shooting_09                OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_09/v_shooting_09_01.mpg     1  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_09/v_shooting_09_02.mpg     1  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_09/v_shooting_09_03.mpg     1  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_09/v_shooting_09_04.mpg     1  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_09/v_shooting_09_05.mpg     1  OK
# Creating    UCF11_updated_mpg/basketball/v_shooting_10                OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_10/v_shooting_10_01.mpg     1  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_10/v_shooting_10_02.mpg     1  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_10/v_shooting_10_03.mpg     1  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_10/v_shooting_10_04.mpg     1  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_10/v_shooting_10_05.mpg     1  OK
# Creating    UCF11_updated_mpg/basketball/v_shooting_11                OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_11/v_shooting_11_01.mpg     1  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_11/v_shooting_11_02.mpg     1  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_11/v_shooting_11_03.mpg     1  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_11/v_shooting_11_04.mpg     1  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_11/v_shooting_11_05.mpg     1  OK
# Creating    UCF11_updated_mpg/basketball/v_shooting_12                OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_12/v_shooting_12_01.mpg     1  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_12/v_shooting_12_02.mpg     1  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_12/v_shooting_12_03.mpg     1  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_12/v_shooting_12_04.mpg     1  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_12/v_shooting_12_05.mpg     1  OK
# Creating    UCF11_updated_mpg/basketball/v_shooting_13                OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_13/v_shooting_13_01.mpg       2  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_13/v_shooting_13_02.mpg     2  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_13/v_shooting_13_03.mpg     2  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_13/v_shooting_13_04.mpg     2  OK
# Creating    UCF11_updated_mpg/basketball/v_shooting_14                OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_14/v_shooting_14_01.mpg     2  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_14/v_shooting_14_02.mpg     2  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_14/v_shooting_14_03.mpg     2  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_14/v_shooting_14_04.mpg     2  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_14/v_shooting_14_05.mpg     2  OK
# Creating    UCF11_updated_mpg/basketball/v_shooting_15                OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_15/v_shooting_15_01.mpg     2  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_15/v_shooting_15_02.mpg     2  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_15/v_shooting_15_03.mpg     2  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_15/v_shooting_15_04.mpg     2  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_15/v_shooting_15_05.mpg     2  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_15/v_shooting_15_06.mpg     2  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_15/v_shooting_15_07.mpg     2  OK
# Creating    UCF11_updated_mpg/basketball/v_shooting_16                OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_16/v_shooting_16_01.mpg     2  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_16/v_shooting_16_02.mpg     2  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_16/v_shooting_16_03.mpg       3  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_16/v_shooting_16_04.mpg     3  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_16/v_shooting_16_05.mpg     3  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_16/v_shooting_16_06.mpg     3  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_16/v_shooting_16_07.mpg     3  OK
# Creating    UCF11_updated_mpg/basketball/v_shooting_17                OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_17/v_shooting_17_01.mpg     3  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_17/v_shooting_17_02.mpg     3  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_17/v_shooting_17_03.mpg     3  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_17/v_shooting_17_04.mpg     3  OK
# Creating    UCF11_updated_mpg/basketball/v_shooting_18                OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_18/v_shooting_18_01.mpg     3  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_18/v_shooting_18_02.mpg     3  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_18/v_shooting_18_03.mpg     3  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_18/v_shooting_18_04.mpg     3  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_18/v_shooting_18_05.mpg     3  OK
# Creating    UCF11_updated_mpg/basketball/v_shooting_19                OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_19/v_shooting_19_01.mpg     3  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_19/v_shooting_19_02.mpg     3  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_19/v_shooting_19_03.mpg     3  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_19/v_shooting_19_04.mpg     3  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_19/v_shooting_19_05.mpg     3  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_19/v_shooting_19_06.mpg     3  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_19/v_shooting_19_07.mpg     3  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_19/v_shooting_19_08.mpg     3  OK
# Creating    UCF11_updated_mpg/basketball/v_shooting_20                OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_20/v_shooting_20_01.mpg       4  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_20/v_shooting_20_02.mpg     4  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_20/v_shooting_20_03.mpg     4  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_20/v_shooting_20_04.mpg     4  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_20/v_shooting_20_05.mpg     4  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_20/v_shooting_20_06.mpg     4  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_20/v_shooting_20_07.mpg     4  OK
# Creating    UCF11_updated_mpg/basketball/v_shooting_21                OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_21/v_shooting_21_01.mpg     4  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_21/v_shooting_21_02.mpg     4  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_21/v_shooting_21_03.mpg     4  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_21/v_shooting_21_04.mpg     4  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_21/v_shooting_21_05.mpg     4  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_21/v_shooting_21_06.mpg     4  OK
# Creating    UCF11_updated_mpg/basketball/v_shooting_22                OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_22/v_shooting_22_01.mpg     4  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_22/v_shooting_22_02.mpg     4  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_22/v_shooting_22_03.mpg     4  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_22/v_shooting_22_04.mpg     4  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_22/v_shooting_22_05.mpg     4  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_22/v_shooting_22_06.mpg     4  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_22/v_shooting_22_07.mpg     4  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_22/v_shooting_22_08.mpg     4  OK
# Creating    UCF11_updated_mpg/basketball/v_shooting_23                OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_23/v_shooting_23_01.mpg     4  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_23/v_shooting_23_02.mpg     4  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_23/v_shooting_23_03.mpg     4  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_23/v_shooting_23_04.mpg     4  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_23/v_shooting_23_05.mpg     4  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_23/v_shooting_23_06.mpg     4  OK
# Creating    UCF11_updated_mpg/basketball/v_shooting_24                OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_24/v_shooting_24_01.mpg     4  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_24/v_shooting_24_02.mpg       5  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_24/v_shooting_24_03.mpg     5  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_24/v_shooting_24_04.mpg     5  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_24/v_shooting_24_05.mpg     5  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_24/v_shooting_24_06.mpg     5  OK
# Creating    UCF11_updated_mpg/basketball/v_shooting_25                OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_25/v_shooting_25_01.mpg     5  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_25/v_shooting_25_02.mpg     5  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_25/v_shooting_25_03.mpg     5  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_25/v_shooting_25_04.mpg     5  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_25/v_shooting_25_05.mpg     5  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_25/v_shooting_25_06.mpg     5  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_25/v_shooting_25_07.mpg     5  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_25/v_shooting_25_08.mpg     5  OK
# Extracting  UCF11_updated_mpg/basketball/v_shooting_25/v_shooting_25_09.mpg     5  OK
# Creating    UCF11_updated_mpg/basketball/Annotation                   OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_01_01.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_01_02.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_01_03.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_01_04.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_01_05.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_01_06.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_01_07.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_02_01.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_02_02.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_02_03.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_02_04.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_02_05.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_02_06.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_03_01.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_03_02.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_03_03.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_03_04.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_03_05.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_03_06.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_04_01.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_04_02.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_04_03.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_04_04.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_05_01.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_05_02.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_05_03.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_05_04.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_06_01.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_06_02.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_06_03.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_06_04.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_07_01.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_07_02.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_07_03.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_07_04.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_08_01.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_08_02.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_08_03.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_08_04.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_09_01.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_09_02.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_09_03.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_09_04.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_09_05.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_10_01.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_10_02.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_10_03.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_10_04.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_10_05.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_11_01.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_11_02.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_11_03.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_11_04.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_11_05.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_12_01.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_12_02.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_12_03.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_12_04.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_12_05.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_13_01.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_13_02.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_13_03.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_13_04.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_14_01.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_14_02.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_14_03.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_14_04.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_14_05.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_15_01.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_15_02.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_15_03.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_15_04.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_15_05.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_15_06.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_15_07.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_16_01.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_16_02.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_16_03.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_16_04.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_16_05.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_16_06.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_16_07.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_17_01.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_17_02.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_17_03.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_17_04.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_18_01.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_18_02.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_18_03.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_18_04.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_18_05.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_19_01.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_19_02.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_19_03.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_19_04.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_19_05.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_19_06.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_19_07.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_19_08.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_20_01.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_20_02.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_20_03.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_20_04.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_20_05.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_20_06.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_20_07.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_21_01.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_21_02.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_21_03.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_21_04.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_21_05.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_21_06.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_22_01.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_22_02.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_22_03.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_22_04.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_22_05.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_22_06.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_22_07.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_22_08.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_23_01.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_23_02.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_23_03.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_23_04.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_23_05.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_23_06.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_24_01.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_24_02.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_24_03.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_24_04.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_24_05.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_24_06.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_25_01.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_25_02.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_25_03.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_25_04.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_25_05.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_25_06.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_25_07.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_25_08.xgtf     5  OK
# Extracting  UCF11_updated_mpg/basketball/Annotation/v_shooting_25_09.xgtf     5  OK
# Creating    UCF11_updated_mpg/biking                                  OK
# Creating    UCF11_updated_mpg/biking/v_biking_01                      OK
# Extracting  UCF11_updated_mpg/biking/v_biking_01/v_biking_01_01.mpg      5  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_01/v_biking_01_02.mpg      5  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_01/v_biking_01_03.mpg      5  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_01/v_biking_01_04.mpg      5  OK
# Creating    UCF11_updated_mpg/biking/v_biking_02                      OK
# Extracting  UCF11_updated_mpg/biking/v_biking_02/v_biking_02_01.mpg      5  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_02/v_biking_02_02.mpg      5  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_02/v_biking_02_03.mpg      5  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_02/v_biking_02_04.mpg        6  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_02/v_biking_02_05.mpg      6  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_02/v_biking_02_06.mpg      6  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_02/v_biking_02_07.mpg      6  OK
# Creating    UCF11_updated_mpg/biking/v_biking_03                      OK
# Extracting  UCF11_updated_mpg/biking/v_biking_03/v_biking_03_01.mpg      6  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_03/v_biking_03_02.mpg      6  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_03/v_biking_03_03.mpg      6  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_03/v_biking_03_04.mpg      6  OK
# Creating    UCF11_updated_mpg/biking/v_biking_04                      OK
# Extracting  UCF11_updated_mpg/biking/v_biking_04/v_biking_04_01.mpg      6  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_04/v_biking_04_02.mpg      6  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_04/v_biking_04_03.mpg      6  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_04/v_biking_04_04.mpg        7  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_04/v_biking_04_05.mpg      7  OK
# Creating    UCF11_updated_mpg/biking/v_biking_05                      OK
# Extracting  UCF11_updated_mpg/biking/v_biking_05/v_biking_05_01.mpg      7  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_05/v_biking_05_02.mpg      7  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_05/v_biking_05_03.mpg      7  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_05/v_biking_05_04.mpg      7  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_05/v_biking_05_05.mpg      7  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_05/v_biking_05_06.mpg      7  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_05/v_biking_05_07.mpg      7  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_05/v_biking_05_08.mpg      7  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_05/v_biking_05_09.mpg      7  OK
# Creating    UCF11_updated_mpg/biking/v_biking_06                      OK
# Extracting  UCF11_updated_mpg/biking/v_biking_06/v_biking_06_01.mpg      7  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_06/v_biking_06_02.mpg      7  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_06/v_biking_06_03.mpg      7  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_06/v_biking_06_04.mpg        8  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_06/v_biking_06_05.mpg      8  OK
# Creating    UCF11_updated_mpg/biking/v_biking_07                      OK
# Extracting  UCF11_updated_mpg/biking/v_biking_07/v_biking_07_01.mpg      8  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_07/v_biking_07_02.mpg      8  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_07/v_biking_07_03.mpg      8  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_07/v_biking_07_04.mpg      8  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_07/v_biking_07_05.mpg      8  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_07/v_biking_07_06.mpg      8  OK
# Creating    UCF11_updated_mpg/biking/v_biking_08                      OK
# Extracting  UCF11_updated_mpg/biking/v_biking_08/v_biking_08_01.mpg      8  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_08/v_biking_08_02.mpg      8  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_08/v_biking_08_03.mpg      8  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_08/v_biking_08_04.mpg      8  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_08/v_biking_08_05.mpg        9  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_08/v_biking_08_06.mpg      9  OK
# Creating    UCF11_updated_mpg/biking/v_biking_09                      OK
# Extracting  UCF11_updated_mpg/biking/v_biking_09/v_biking_09_01.mpg      9  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_09/v_biking_09_02.mpg      9  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_09/v_biking_09_03.mpg      9  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_09/v_biking_09_04.mpg      9  OK
# Creating    UCF11_updated_mpg/biking/v_biking_10                      OK
# Extracting  UCF11_updated_mpg/biking/v_biking_10/v_biking_10_01.mpg      9  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_10/v_biking_10_02.mpg      9  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_10/v_biking_10_03.mpg      9  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_10/v_biking_10_04.mpg      9  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_10/v_biking_10_05.mpg      9  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_10/v_biking_10_06.mpg      9  OK
# Creating    UCF11_updated_mpg/biking/v_biking_11                      OK
# Extracting  UCF11_updated_mpg/biking/v_biking_11/v_biking_11_01.mpg       10  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_11/v_biking_11_02.mpg     10  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_11/v_biking_11_03.mpg     10  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_11/v_biking_11_04.mpg     10  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_11/v_biking_11_05.mpg     10  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_11/v_biking_11_06.mpg     10  OK
# Creating    UCF11_updated_mpg/biking/v_biking_12                      OK
# Extracting  UCF11_updated_mpg/biking/v_biking_12/v_biking_12_01.mpg     10  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_12/v_biking_12_02.mpg     10  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_12/v_biking_12_03.mpg     10  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_12/v_biking_12_04.mpg     10  OK
# Creating    UCF11_updated_mpg/biking/v_biking_13                      OK
# Extracting  UCF11_updated_mpg/biking/v_biking_13/v_biking_13_01.mpg     10  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_13/v_biking_13_02.mpg     10  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_13/v_biking_13_03.mpg     10  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_13/v_biking_13_04.mpg     10  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_13/v_biking_13_05.mpg     10  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_13/v_biking_13_06.mpg     1 11  OK
# Creating    UCF11_updated_mpg/biking/v_biking_14                      OK
# Extracting  UCF11_updated_mpg/biking/v_biking_14/v_biking_14_01.mpg     11  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_14/v_biking_14_02.mpg     11  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_14/v_biking_14_03.mpg     11  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_14/v_biking_14_04.mpg     11  OK
# Creating    UCF11_updated_mpg/biking/v_biking_15                      OK
# Extracting  UCF11_updated_mpg/biking/v_biking_15/v_biking_15_01.mpg     11  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_15/v_biking_15_02.mpg     11  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_15/v_biking_15_03.mpg     11  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_15/v_biking_15_04.mpg     11  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_15/v_biking_15_05.mpg     11  OK
# Creating    UCF11_updated_mpg/biking/v_biking_16                      OK
# Extracting  UCF11_updated_mpg/biking/v_biking_16/v_biking_16_01.mpg     11  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_16/v_biking_16_02.mpg     11  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_16/v_biking_16_03.mpg     11  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_16/v_biking_16_04.mpg     11  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_16/v_biking_16_05.mpg     1 12  OK
# Creating    UCF11_updated_mpg/biking/v_biking_17                      OK
# Extracting  UCF11_updated_mpg/biking/v_biking_17/v_biking_17_01.mpg     12  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_17/v_biking_17_02.mpg     12  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_17/v_biking_17_03.mpg     12  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_17/v_biking_17_04.mpg     12  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_17/v_biking_17_05.mpg     12  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_17/v_biking_17_06.mpg     12  OK
# Creating    UCF11_updated_mpg/biking/v_biking_18                      OK
# Extracting  UCF11_updated_mpg/biking/v_biking_18/v_biking_18_01.mpg     12  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_18/v_biking_18_02.mpg     12  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_18/v_biking_18_03.mpg     12  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_18/v_biking_18_04.mpg     12  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_18/v_biking_18_05.mpg     12  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_18/v_biking_18_06.mpg     12  OK
# Creating    UCF11_updated_mpg/biking/v_biking_19                      OK
# Extracting  UCF11_updated_mpg/biking/v_biking_19/v_biking_19_01.mpg     12  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_19/v_biking_19_02.mpg     12  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_19/v_biking_19_03.mpg     12  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_19/v_biking_19_04.mpg     1 13  OK
# Creating    UCF11_updated_mpg/biking/v_biking_20                      OK
# Extracting  UCF11_updated_mpg/biking/v_biking_20/v_biking_20_01.mpg     13  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_20/v_biking_20_02.mpg     13  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_20/v_biking_20_03.mpg     13  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_20/v_biking_20_04.mpg     13  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_20/v_biking_20_05.mpg     13  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_20/v_biking_20_06.mpg     13  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_20/v_biking_20_07.mpg     13  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_20/v_biking_20_08.mpg     13  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_20/v_biking_20_09.mpg     1 14  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_20/v_biking_20_10.mpg     14  OK
# Creating    UCF11_updated_mpg/biking/v_biking_21                      OK
# Extracting  UCF11_updated_mpg/biking/v_biking_21/v_biking_21_01.mpg     14  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_21/v_biking_21_02.mpg     14  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_21/v_biking_21_03.mpg     14  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_21/v_biking_21_04.mpg     14  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_21/v_biking_21_05.mpg     14  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_21/v_biking_21_06.mpg     14  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_21/v_biking_21_07.mpg     14  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_21/v_biking_21_08.mpg     14  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_21/v_biking_21_09.mpg     1 15  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_21/v_biking_21_10.mpg     15  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_21/v_biking_21_11.mpg     15  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_21/v_biking_21_12.mpg     15  OK
# Creating    UCF11_updated_mpg/biking/v_biking_22                      OK
# Extracting  UCF11_updated_mpg/biking/v_biking_22/v_biking_22_01.mpg     15  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_22/v_biking_22_02.mpg     15  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_22/v_biking_22_03.mpg     15  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_22/v_biking_22_04.mpg     15  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_22/v_biking_22_05.mpg     15  OK
# Creating    UCF11_updated_mpg/biking/v_biking_23                      OK
# Extracting  UCF11_updated_mpg/biking/v_biking_23/v_biking_23_01.mpg     1 16  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_23/v_biking_23_02.mpg     16  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_23/v_biking_23_03.mpg     16  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_23/v_biking_23_04.mpg     16  OK
# Creating    UCF11_updated_mpg/biking/v_biking_24                      OK
# Extracting  UCF11_updated_mpg/biking/v_biking_24/v_biking_24_01.mpg     16  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_24/v_biking_24_02.mpg     16  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_24/v_biking_24_03.mpg     16  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_24/v_biking_24_04.mpg     16  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_24/v_biking_24_05.mpg     16  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_24/v_biking_24_06.mpg     1 17  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_24/v_biking_24_07.mpg     17  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_24/v_biking_24_08.mpg     17  OK
# Creating    UCF11_updated_mpg/biking/v_biking_25                      OK
# Extracting  UCF11_updated_mpg/biking/v_biking_25/v_biking_25_01.mpg     17  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_25/v_biking_25_02.mpg     17  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_25/v_biking_25_03.mpg     17  OK
# Extracting  UCF11_updated_mpg/biking/v_biking_25/v_biking_25_04.mpg     17  OK
# Creating    UCF11_updated_mpg/biking/Annotation                       OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_01_01.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_01_02.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_01_03.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_01_04.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_03_03.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_03_04.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_04_01.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_04_02.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_04_03.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_04_04.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_04_05.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_05_01.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_05_06.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_05_07.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_05_08.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_05_09.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_06_04.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_06_05.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_07_01.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_05_02.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_05_03.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_05_04.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_05_05.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_07_02.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_07_03.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_06_01.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_06_02.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_06_03.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_07_04.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_07_05.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_07_06.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_08_01.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_08_05.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_08_06.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_09_01.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_09_02.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_08_02.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_08_03.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_08_04.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_10_01.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_10_02.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_09_03.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_09_04.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_10_03.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_10_04.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_10_05.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_10_06.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_11_05.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_12_01.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_11_01.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_11_02.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_11_03.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_11_04.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_12_02.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_11_06.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_13_04.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_13_06.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_12_03.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_12_04.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_13_01.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_13_02.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_13_03.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_15_01.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_13_05.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_15_02.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_14_01.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_14_02.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_14_03.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_14_04.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_15_03.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_15_04.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_15_05.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_16_01.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_16_02.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_16_03.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_16_04.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_16_05.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_17_01.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_17_02.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_17_03.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_17_04.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_17_05.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_17_06.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_18_02.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_18_05.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_18_01.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_18_06.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_18_03.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_18_04.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_20_01.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_20_02.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_19_01.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_19_02.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_19_03.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_19_04.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_20_03.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_20_04.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_20_05.xgtf     17  OK
# Extracting  UCF11_updated_mpg/biking/Annotation/v_biking_20_06.xgtf     17  OK
# ...
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_13/v_walk_dog_13_04.mpg    94  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_13/v_walk_dog_13_05.mpg    94  OK
# Creating    UCF11_updated_mpg/walking/v_walk_dog_14                   OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_14/v_walk_dog_14_01.mpg    9 95  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_14/v_walk_dog_14_02.mpg    95  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_14/v_walk_dog_14_03.mpg    95  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_14/v_walk_dog_14_04.mpg    95  OK
# Creating    UCF11_updated_mpg/walking/v_walk_dog_15                   OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_15/v_walk_dog_15_01.mpg    95  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_15/v_walk_dog_15_02.mpg    95  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_15/v_walk_dog_15_03.mpg    95  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_15/v_walk_dog_15_04.mpg    95  OK
# Creating    UCF11_updated_mpg/walking/v_walk_dog_16                   OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_16/v_walk_dog_16_01.mpg    95  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_16/v_walk_dog_16_02.mpg    95  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_16/v_walk_dog_16_03.mpg    95  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_16/v_walk_dog_16_04.mpg    9 96  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_16/v_walk_dog_16_05.mpg    96  OK
# Creating    UCF11_updated_mpg/walking/v_walk_dog_17                   OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_17/v_walk_dog_17_01.mpg    96  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_17/v_walk_dog_17_02.mpg    96  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_17/v_walk_dog_17_03.mpg    96  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_17/v_walk_dog_17_04.mpg    96  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_17/v_walk_dog_17_05.mpg    96  OK
# Creating    UCF11_updated_mpg/walking/v_walk_dog_18                   OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_18/v_walk_dog_18_01.mpg    96  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_18/v_walk_dog_18_02.mpg    96  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_18/v_walk_dog_18_03.mpg    96  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_18/v_walk_dog_18_04.mpg    96  OK
# Creating    UCF11_updated_mpg/walking/v_walk_dog_19                   OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_19/v_walk_dog_19_01.mpg    96  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_19/v_walk_dog_19_02.mpg    9 97  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_19/v_walk_dog_19_03.mpg    97  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_19/v_walk_dog_19_04.mpg    97  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_19/v_walk_dog_19_05.mpg    97  OK
# Creating    UCF11_updated_mpg/walking/v_walk_dog_20                   OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_20/v_walk_dog_20_01.mpg    97  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_20/v_walk_dog_20_02.mpg    97  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_20/v_walk_dog_20_03.mpg    97  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_20/v_walk_dog_20_04.mpg    97  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_20/v_walk_dog_20_05.mpg    9 98  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_20/v_walk_dog_20_06.mpg    98  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_20/v_walk_dog_20_07.mpg    98  OK
# Creating    UCF11_updated_mpg/walking/v_walk_dog_21                   OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_21/v_walk_dog_21_01.mpg    98  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_21/v_walk_dog_21_02.mpg    98  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_21/v_walk_dog_21_03.mpg    98  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_21/v_walk_dog_21_04.mpg    98  OK
# Creating    UCF11_updated_mpg/walking/v_walk_dog_22                   OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_22/v_walk_dog_22_01.mpg    98  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_22/v_walk_dog_22_02.mpg    98  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_22/v_walk_dog_22_03.mpg    98  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_22/v_walk_dog_22_04.mpg    98  OK
# Creating    UCF11_updated_mpg/walking/v_walk_dog_23                   OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_23/v_walk_dog_23_01.mpg    98  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_23/v_walk_dog_23_02.mpg    98  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_23/v_walk_dog_23_03.mpg    9 99  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_23/v_walk_dog_23_04.mpg    99  OK
# Creating    UCF11_updated_mpg/walking/v_walk_dog_24                   OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_24/v_walk_dog_24_01.mpg    99  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_24/v_walk_dog_24_02.mpg    99  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_24/v_walk_dog_24_03.mpg    99  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_24/v_walk_dog_24_04.mpg    99  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_24/v_walk_dog_24_05.mpg    99  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_24/v_walk_dog_24_06.mpg    99  OK
# Creating    UCF11_updated_mpg/walking/v_walk_dog_25                   OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_25/v_walk_dog_25_01.mpg    99  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_25/v_walk_dog_25_02.mpg    99  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_25/v_walk_dog_25_03.mpg    99  OK
# Extracting  UCF11_updated_mpg/walking/v_walk_dog_25/v_walk_dog_25_04.mpg    99  OK
# Creating    UCF11_updated_mpg/walking/Annotation                      OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_01_02.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_01_03.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_01_04.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_02_01.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_02_02.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_02_03.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_02_04.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_02_05.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_02_06.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_03_01.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_03_02.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_03_03.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_03_04.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_03_05.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_04_01.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_04_02.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_04_03.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_04_04.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_04_05.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_05_01.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_05_02.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_05_03.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_05_04.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_05_05.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_06_01.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_06_02.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_09_01.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_07_01.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_07_02.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_09_02.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_09_03.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_09_04.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_09_05.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_09_06.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_10_02.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_10_03.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_10_04.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_10_05.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_11_01.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_11_02.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_11_03.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_11_04.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_11_05.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_12_02.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_10_01.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_12_03.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_12_04.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_12_05.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_13_02.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_13_03.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_13_04.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_13_05.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_14_01.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_14_02.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_12_01.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_14_03.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_14_04.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_15_01.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_15_02.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_13_01.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_15_03.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_15_04.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_16_01.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_16_02.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_16_03.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_16_04.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_16_05.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_17_01.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_17_02.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_17_03.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_17_04.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_17_05.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_18_01.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_18_02.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_18_03.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_18_04.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_19_01.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_19_02.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_19_03.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_19_04.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_19_05.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_20_01.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_20_02.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_20_03.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_20_04.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_20_05.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_20_06.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_20_07.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_21_01.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_21_02.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_21_03.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_21_04.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_22_01.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_22_02.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_22_04.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_22_03.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_23_01.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_23_02.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_23_03.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_23_04.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_24_01.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_24_02.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_24_03.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_24_04.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_24_05.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_24_06.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_25_01.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_25_02.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_25_03.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_25_04.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_01_01.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_06_03.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_06_04.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_06_05.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_07_03.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_07_04.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_07_05.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_07_06.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_08_01.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_08_02.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_08_03.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_08_04.xgtf    99  OK
# Extracting  UCF11_updated_mpg/walking/Annotation/v_walk_dog_08_05.xgtf    99  OK
# All OK

# %% [markdown]
# ### Exploring data

# %% [markdown]
# Let's explore the basic statistics of the dataset.

# %%
def statistics(path_dataset):
  classes = os.listdir(path_dataset)
  num_classes = len(classes)
  dictionary = {}
  for name in classes:
    num_videos = len(os.listdir("{}/{}".format(path_dataset,name)))-1
    total_videos = len(os.listdir("{}/{}/Annotation".format(path_dataset,name)))
    dictionary[name] = {'unique_videos': num_videos, 'total_videos': total_videos}
  return dictionary

# %%
path_dataset = "/content/UCF11_updated_mpg"
out = statistics(path_dataset)
pd.DataFrame.from_dict(out)
# Out:
#                swing  tennis_swing  basketball  horse_riding  biking  \
# unique_videos     25            25          25            25      25
# total_videos     138           167         141           198     144
#
#                volleyball_spiking  walking  soccer_juggling  golf_swing  \
# unique_videos                  25       25               25          25
# total_videos                  109      123              156         142
#
#                trampoline_jumping  diving
# unique_videos                  25      25
# total_videos                  111     156

# %% [markdown]
# ### Visualize Videos

# %% [markdown]
# Here we can visualize a selected video from the dataset.

# %%
path_sample = "/content/UCF11_updated_mpg/basketball/v_shooting_08/v_shooting_08_01.mpg"

# %%
import imageio
import os

# load the video file
clip = os.path.abspath(path_sample)

# create a function
def gifMkaker(inputPath, targetFormat, duration):
    # giving a output path
    outputPath = "animation" + targetFormat

    print(f'converting {inputPath} \n to {outputPath}')

    reader = imageio.get_reader(inputPath)
    # define fps of the gif
    # The keyword `fps` is no longer supported.
    # Use `duration`(in ms) instead, e.g. `fps=50` == `duration=20` (1000 * 1/50)
    fps = reader.get_meta_data()['duration']

    writer = imageio.get_writer(outputPath, duration=fps)

    for i, frames in enumerate(reader):
        writer.append_data(frames)
        # print(f'Frame{frames}')
        if i > duration:
          break
    print('done')
    writer.close()

gifMkaker(clip, '.gif', 30)
# Out:
# converting /content/UCF11_updated_mpg/basketball/v_shooting_08/v_shooting_08_01.mpg
#  to animation.gif
# done

# %%
from IPython.display import Image as ImageD
ImageD(filename="animation.gif")

# %% [markdown]
# ### Preprocess data

# %% [markdown]
# Here we have two main functions for preprocess the videos.
#
# The `vids_to_frames` function convert from video in mpg formart to N frames in jpg format.

# %%
def vids_to_frames(path_videos, action, path):
    path_action = os.path.join(path_videos, action)
    list_cams = os.listdir(path_action)
    for cam in list_cams:
        path_cam_save = os.path.join(path, cam.split('.')[0])
        os.mkdir(path_cam_save)
        vid_path = os.path.join(path_action, cam)
        vidcap = cv2.VideoCapture(vid_path)
        success,image = vidcap.read()
        count = 0
        while success:
            path_cam_frame = os.path.join(path_cam_save, f'frame_{count}.jpg')
            cv2.imwrite(path_cam_frame, image)
            success,image = vidcap.read()
            count += 1

# %% [markdown]
# The `preprocess_data` function divides the data into train and val, and separate the videos into frames using the vids_to_frames function.
#
# We need to define the `paths` and `split_size`.

# %%
def preprocess_data(path_data, train_path, val_path, split_size):
    if not os.path.exists(train_path) and not os.path.exists(val_path):
        os.mkdir(train_path)
        os.mkdir(val_path)
        list_classes = os.listdir(path_data)
        for class_name in tqdm(list_classes):
            train_class = os.path.join(train_path, class_name)
            os.mkdir(train_class)
            val_class = os.path.join(val_path, class_name)
            os.mkdir(val_class)
            path_videos = os.path.join(path_data, class_name)
            list_actions = os.listdir(path_videos)
            list_actions = [a for a in list_actions if a != 'Annotation']
            num_actions = len(list_actions)
            num_actions_train = int(num_actions*split_size)
            action_train = list_actions[:num_actions_train]
            action_test = list_actions[num_actions_train:]
            for action in list_actions:
                if action in action_train:
                    vids_to_frames(path_videos, action, train_class)
                else:
                    vids_to_frames(path_videos, action, val_class)

# %% [markdown]
# Defining the paths to training data and validation data. Then we preprocess the whole dataset with `split_size=0.8`

# %%
path_data = '/content/UCF11_updated_mpg'
train_path = '/content/train'
val_path = '/content/val'

# %%
preprocess_data(path_data, train_path, val_path, 0.8) # it takes about ~4min
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]

# %% [markdown]
# ### Video dataset

# %% [markdown]
# Now, we will create our dataset for UCF11 dataset.

# %% [markdown]
# This is the Dataset Class created to transform and load the videos into the model using uniform temporal sampling. Note that `np.linspace` function allows to do that.
#
# <figure>
# <center>
# <img src='https://www.sharpsightlabs.com/wp-content/uploads/2018/10/visual-representation-of-np-linspace-0-100-5.png' width="500" />
# </center>
# </figure>

# %%
class VideoDataset(data.Dataset):

    def __init__(self, path_data, num_frames, transform=None):
        # This code loads all the videos and prepares the labels.
        self.list_classes = os.listdir(path_data)
        self.list_data = []
        self.list_labels = []
        for idx, c in enumerate(self.list_classes):
            path_class_data = os.path.join(path_data, c)
            class_data = os.listdir(path_class_data)
            self.list_data.extend(class_data)
            self.list_labels.extend([idx]*len(class_data))
        self.root_dir = path_data
        self.transform = transform
        self.num_frames = num_frames

    def __len__(self):
        # The number of all videos in the set
        return len(self.list_data)

    def natural_keys(self, text):
        return int(re.split(r'(\d+)', text)[1])

    def __getitem__(self, idx):
        # function to get the item or video i
        elem = self.list_data[idx]
        label = self.list_labels[idx]
        path_elem = os.path.join(self.root_dir, self.list_classes[label], elem)
        frames_elem = os.listdir(path_elem)
        frames_elem.sort(key=self.natural_keys)
        idx_frames = np.linspace(0, len(frames_elem)-1, num=self.num_frames, dtype = int)
        list_frames = []
        for ind_frame in idx_frames:
            frame_name = frames_elem[ind_frame]
            img_name = os.path.join(path_elem, frame_name)
            frame = Image.open(img_name).convert('RGB')
            list_frames.append(frame)
        process_data = self.transform(list_frames)
        return process_data, label

# %% [markdown]
# ### Video transformation

# %% [markdown]
# These classes and functions are used to augment the video data, which is essential to train the model and avoid overfitting.

# %%
class GroupRandomHorizontalFlip(object):
    """Randomly horizontally flips the given PIL.Image with a probability of 0.5
    """
    def __init__(self, is_flow=False):
        self.is_flow = is_flow

    def __call__(self, img_group, is_flow=False):
        v = random.random()
        if v < 0.5:
            ret = [img.transpose(Image.FLIP_LEFT_RIGHT) for img in img_group]
            if self.is_flow:
                for i in range(0, len(ret), 2):
                    ret[i] = ImageOps.invert(ret[i])  # invert flow pixel values when flipping
            return ret
        else:
            return img_group

# %%
class GroupMultiScaleCrop(object):

    def __init__(self, input_size, scales=None, max_distort=1, fix_crop=True, more_fix_crop=True):
        self.scales = scales if scales is not None else [1, .875, .75, .66]
        self.max_distort = max_distort
        self.fix_crop = fix_crop
        self.more_fix_crop = more_fix_crop
        self.input_size = input_size if not isinstance(input_size, int) else [input_size, input_size]
        self.interpolation = Image.BILINEAR

    def __call__(self, img_group):

        im_size = img_group[0].size

        crop_w, crop_h, offset_w, offset_h = self._sample_crop_size(im_size)
        crop_img_group = [img.crop((offset_w, offset_h, offset_w + crop_w, offset_h + crop_h)) for img in img_group]
        ret_img_group = [img.resize((self.input_size[0], self.input_size[1]), self.interpolation)
                         for img in crop_img_group]
        return ret_img_group

    def _sample_crop_size(self, im_size):
        image_w, image_h = im_size[0], im_size[1]

        # find a crop size
        base_size = min(image_w, image_h)
        crop_sizes = [int(base_size * x) for x in self.scales]
        crop_h = [self.input_size[1] if abs(x - self.input_size[1]) < 3 else x for x in crop_sizes]
        crop_w = [self.input_size[0] if abs(x - self.input_size[0]) < 3 else x for x in crop_sizes]

        pairs = []
        for i, h in enumerate(crop_h):
            for j, w in enumerate(crop_w):
                if abs(i - j) <= self.max_distort:
                    pairs.append((w, h))

        crop_pair = random.choice(pairs)
        if not self.fix_crop:
            w_offset = random.randint(0, image_w - crop_pair[0])
            h_offset = random.randint(0, image_h - crop_pair[1])
        else:
            w_offset, h_offset = self._sample_fix_offset(image_w, image_h, crop_pair[0], crop_pair[1])

        return crop_pair[0], crop_pair[1], w_offset, h_offset

    def _sample_fix_offset(self, image_w, image_h, crop_w, crop_h):
        offsets = self.fill_fix_offset(self.more_fix_crop, image_w, image_h, crop_w, crop_h)
        return random.choice(offsets)

    @staticmethod
    def fill_fix_offset(more_fix_crop, image_w, image_h, crop_w, crop_h):
        w_step = (image_w - crop_w) // 4
        h_step = (image_h - crop_h) // 4

        ret = list()
        ret.append((0, 0))  # upper left
        ret.append((4 * w_step, 0))  # upper right
        ret.append((0, 4 * h_step))  # lower left
        ret.append((4 * w_step, 4 * h_step))  # lower right
        ret.append((2 * w_step, 2 * h_step))  # center

        if more_fix_crop:
            ret.append((0, 2 * h_step))  # center left
            ret.append((4 * w_step, 2 * h_step))  # center right
            ret.append((2 * w_step, 4 * h_step))  # lower center
            ret.append((2 * w_step, 0 * h_step))  # upper center

            ret.append((1 * w_step, 1 * h_step))  # upper left quarter
            ret.append((3 * w_step, 1 * h_step))  # upper right quarter
            ret.append((1 * w_step, 3 * h_step))  # lower left quarter
            ret.append((3 * w_step, 3 * h_step))  # lower righ quarter

        return ret

# %%
class GroupScale(object):
    """ Rescales the input PIL.Image to the given 'size'.
    'size' will be the size of the smaller edge.
    For example, if height > width, then image will be
    rescaled to (size * height / width, size)
    size: size of the smaller edge
    interpolation: Default: PIL.Image.BILINEAR
    """

    def __init__(self, size, interpolation=Image.BILINEAR):
        self.worker = torchvision.transforms.Scale(size, interpolation)

    def __call__(self, img_group):
        return [self.worker(img) for img in img_group]


class GroupCenterCrop(object):
    def __init__(self, size):
        self.worker = torchvision.transforms.CenterCrop(size)

    def __call__(self, img_group):
        return [self.worker(img) for img in img_group]


class Stack(object):

    def __init__(self, roll=False):
        self.roll = roll

    def __call__(self, img_group):
        if img_group[0].mode == 'L':
            return np.concatenate([np.expand_dims(x, 2) for x in img_group], axis=2)
        elif img_group[0].mode == 'RGB':
            if self.roll:
                return np.concatenate([np.array(x)[:, :, ::-1] for x in img_group], axis=2)
            else:
                return np.concatenate(img_group, axis=2)


class ToTorchFormatTensor(object):
    """ Converts a PIL.Image (RGB) or numpy.ndarray (H x W x C) in the range [0, 255]
    to a torch.FloatTensor of shape (C x H x W) in the range [0.0, 1.0] """

    def __init__(self, div=True):
        self.div = div

    def __call__(self, pic):
        if isinstance(pic, np.ndarray):
            # handle numpy array
            img = torch.from_numpy(pic).permute(2, 0, 1).contiguous()
        else:
            # handle PIL Image
            img = torch.ByteTensor(torch.ByteStorage.from_buffer(pic.tobytes()))
            img = img.view(pic.size[1], pic.size[0], len(pic.mode))
            # put it from HWC to CHW format
            # yikes, this transpose takes 80% of the loading time/CPU
            img = img.transpose(0, 1).transpose(0, 2).contiguous()
        return img.float().div(255) if self.div else img.float()


class GroupNormalize(object):
    def __init__(self, mean, std):
        self.mean = mean
        self.std = std

    def __call__(self, tensor):
        rep_mean = self.mean * (tensor.size()[0] // len(self.mean))
        rep_std = self.std * (tensor.size()[0] // len(self.std))

        # TODO: make efficient
        for t, m, s in zip(tensor, rep_mean, rep_std):
            t.sub_(m).div_(s)

        return tensor


def get_transform():
    cropping = torchvision.transforms.Compose([
        GroupScale(256),
        GroupCenterCrop(224),
    ])
    transform = torchvision.transforms.Compose([
        cropping,
        Stack(roll=False),
        ToTorchFormatTensor(div=True),
        GroupNormalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
    return transform

def scale_size(input_size):
    return input_size * 256 // 224

# %% [markdown]
# ## 3. Dataloader

# %% [markdown]
# ### Instance transformation

# %% [markdown]
# Instantiate the transformations for training and validation.
# It is necessary to define a fixed `input_size`, and normalization parameters (`input_mean` and `input_std`).

# %%
# size of frame
input_size = 224
# normalization
input_mean = [0.485, 0.456, 0.406]
input_std = [0.229, 0.224, 0.225]
# backbone name
arch = "Resnet"

# %%
transform_train = torchvision.transforms.Compose([
                                                  GroupMultiScaleCrop(input_size, [1, .875, .75, .66]),
                                                  GroupRandomHorizontalFlip(is_flow=False),
                                                  Stack(roll=(arch in ['BNInception', 'InceptionV3'])),
                                                  ToTorchFormatTensor(div=(arch not in ['BNInception', 'InceptionV3'])),
                                                  GroupNormalize(input_mean, input_std)
                                                  ])

# %%
transform_val = torchvision.transforms.Compose([
                       GroupCenterCrop(input_size),
                       Stack(roll=(arch in ['BNInception', 'InceptionV3'])),
                       ToTorchFormatTensor(div=(arch not in ['BNInception', 'InceptionV3'])),
                       GroupNormalize(input_mean, input_std)
                   ])

# %% [markdown]
# ### Instance video dataset

# %% [markdown]
# Instantiate the VideoDataset for training and validation with 8 frames per video

# %%
num_frames = 5

# %%
dataset_train = VideoDataset('/content/train', num_frames, transform_train)
dataset_val = VideoDataset('/content/val', num_frames, transform_val)

# %%
dataset_val[0][0].shape
# Out:
# torch.Size([15, 224, 224])

# %% [markdown]
# ## 4. Create model

# %% [markdown]
# This is the model used to classify the videos. It is based on a pre-trained ResNet-34 backbone and avg pooling to reduce the temporal dimension.
#
# We are going to build the two versions we explored in class. `VideoCNN`, which is a model based solely on CNN without temporal processing, and `VideoRNN`, which is a model based on CNN and RNN to process visual and temporal information.

# %%
class VideoCNN(nn.Module):
    def __init__(self, num_classes=2, num_frames=8):
        super(VideoCNN, self).__init__()
        # create a pre-trained cnn
        self.net = models.resnet34(pretrained=True)
        # create a classifier
        self.fc = nn.Linear(in_features=self.net.fc.in_features,
                            out_features=num_classes)
        self.net.fc = nn.Identity()
        self.num_segments = num_frames

    def forward(self, inputs):
        # flatten input
        inputs = inputs.view((-1, 3) + inputs.size()[-2:])
        # compute frames representation with cnn
        out = self.net(inputs)
        # unflatten output of cnn
        out = out.view((-1, self.num_segments) + out.size()[1:])
        # average pooling of representations
        out = torch.mean(out, dim = 1)
        # classify
        out = self.fc(out)
        return out

# %%
class VideoRNN(nn.Module):
    def __init__(self, num_classes, num_frames=8):
        super(VideoRNN, self).__init__()
        # create a pre-trained cnn
        self.net = models.resnet34(pretrained=True)
        # create a rnn (1 layer)
        self.rnn = nn.GRU(input_size=self.net.fc.in_features,
                          hidden_size=self.net.fc.in_features,
                          num_layers=1,
                          batch_first=True)
        self.dropout= nn.Dropout(0.1)
        # create a classifier
        self.fc = nn.Linear(in_features=self.net.fc.in_features,
                            out_features=num_classes)
        self.net.fc = nn.Identity()
        self.num_segments = num_frames

    def forward(self, inputs):
        # flatten input
        inputs = inputs.view((-1, 3) + inputs.size()[-2:])
        # compute representation with cnn
        out = self.net(inputs)
        # unflatten output of cnn
        out = out.view((-1, self.num_segments) + out.size()[1:])
        # processing frames representations with rnn
        bz, seq, dim = out.shape
        h0 = torch.randn(1, bz, dim, device=inputs.device)
        out, hn = self.rnn(out, h0)
        # classify using the last frame representation
        out = self.dropout(out[:,-1])
        out = self.fc(out)
        return out

# %% [markdown]
# ### Instance model

# %% [markdown]
# Instantiate the model. We can decide to use `VideoCNN` or `VideoRNN`.

# %%
num_classes = len(dataset_train.list_classes)
model_type = "cnn+rnn"

if model_type == "cnn+rnn":
  model = VideoRNN(num_classes, num_frames)
elif model_type == "cnn":
  model = VideoCNN(num_classes, num_frames)
# Out:
# /usr/local/lib/python3.13/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.13/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100%|██████████| 83.3M/83.3M [00:00<00:00, 189MB/s]

# %% [markdown]
# ## 5. Train the model

# %% [markdown]
# Train the model during 12 epoch

# %%
num_epochs = 3

# %%
device = torch.device("cuda")
model = model.to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %%
batch_size = 40

trainloader = torch.utils.data.DataLoader(dataset_train, batch_size=batch_size, shuffle=True)
testloader = torch.utils.data.DataLoader(dataset_val, batch_size=batch_size, shuffle=False)

dataloaders={'train': trainloader, 'val':testloader}
dataset_sizes = {'train': len(dataset_train), 'val': len(dataset_val)}

# %%
def train_model(model, criterion, optimizer, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    dict_acc = {'train': [], 'val': []}
    dict_loss = {'train': [], 'val': []}
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0
            num_elem = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    preds = torch.argmax(outputs, dim = 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                num_elem += inputs.size(0)

            epoch_loss = running_loss / num_elem
            epoch_acc = running_corrects.double() / num_elem

            dict_acc[phase].append(epoch_acc)
            dict_loss[phase].append(epoch_loss)
            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, dict_acc, dict_loss

# %%
model, dict_acc, dict_loss = train_model(model, criterion, optimizer, num_epochs=num_epochs)
# Out:
# Epoch 0/2
# ----------
# train Loss: 2.2485 Acc: 0.2618
# val Loss: 2.0563 Acc: 0.3770
#
# Epoch 1/2
# ----------
# train Loss: 1.8085 Acc: 0.5444
# val Loss: 1.6185 Acc: 0.5443
#
# Epoch 2/2
# ----------
# train Loss: 1.3325 Acc: 0.7135
# val Loss: 1.2537 Acc: 0.6754
#
# Training complete in 2m 55s
# Best val Acc: 0.675410

# %% [markdown]
# ## 6. Train Graphs

# %%
def parse_data(data):
    new_data = []
    for d in data:
        new_data.append(d.item())
    return new_data

# %%
epochs = list(range(num_epochs))
plt.plot(epochs, parse_data(dict_acc['train']), 'r', label='Train')
plt.plot(epochs, parse_data(dict_acc['val']), 'b', label='Val')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %% [markdown]
# ## 7. Positive and Negative examples

# %%
def getInferenceModel(model, testloader):
    for inputs, labels in testloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = model(inputs)
        preds = torch.argmax(outputs, dim = 1)
        break
    return preds, inputs, labels

# %%
def plot_example(dataset, idx, pred):

    fig=plt.figure(figsize=(20, 8))
    columns = 4
    rows = 2
    elem = dataset.list_data[idx]
    label = dataset.list_labels[idx]
    fig.suptitle('GT: {}, P: {}'.format(dataset.list_classes[label], dataset.list_classes[pred]), fontsize=16)
    path_elem = os.path.join(dataset.root_dir, dataset.list_classes[label], elem)
    frames_elem = os.listdir(path_elem)
    frames_elem.sort(key=dataset.natural_keys)
    idx_frames = np.linspace(0, len(frames_elem)-1, num=dataset.num_frames, dtype = int)
    list_frames = []
    for i, ind_frame in enumerate(idx_frames):
        frame_name = frames_elem[ind_frame]
        img_name = os.path.join(path_elem, frame_name)
        frame = Image.open(img_name).convert('RGB')
        ax = fig.add_subplot(rows, columns, i+1)
        ax.set_title("t = {}".format(ind_frame))
        ax.axis('off')
        plt.imshow(frame)

# %%
model.eval()
testloader = torch.utils.data.DataLoader(dataset_val, batch_size=30, shuffle=False)

# %%
preds, inputs, labels = getInferenceModel(model, testloader)

# %%
torch.cuda.empty_cache()

# %%
good_examples = np.where((preds == labels).cpu() == True)[0]
good_examples
# Out:
# array([ 1,  3,  6,  7,  8,  9, 10, 13, 14, 15, 16, 17, 18, 19, 24, 25, 26,
#        27, 28, 29])

# %%
bad_examples = np.where((preds != labels).cpu() == True)[0]
bad_examples
# Out:
# array([ 0,  2,  4,  5, 11, 12, 20, 21, 22, 23])

# %%
idx = good_examples[1]
plot_example(dataset_val, idx, preds[idx])

# %%
idx = bad_examples[-1]
plot_example(dataset_val, idx, preds[idx])

# %% [markdown]
# ## 8. Activity

# %% [markdown]
# In this section, you will be asked about the topics studied in the theoretical and practical class.

# %% [markdown]
# 1. What are the main challenges of video analysis?

# %% [markdown]
# Si nos referimos a los problemas que ha intentando resolver el análisis de video, se encuentran:
#
# 1. Visual Object Tracking: Hacer el seguimiento de una persona/objeto durante un video
# 2. Action Classification/Recognition: Identificar en los distintos momentos de un video las acciones que se están realizado
# 3. Complex Action Recognition: Identificar multiples acciones simultáneas dentro de un video
# 4. Egocentric Action Recognition: Identificar las acciones realizadas en un video en primera persona
#
# Entre otros

# %% [markdown]
# 2. Why is video analysis important?

# %% [markdown]
# El análisis de video es muy importante, ya que tiene aplicaciones muy útiles en el mundo real. Por ejemplo:
#
# 1. Análisis de cámaras de video
# 2. Deportes
# 3. Robótica
# 4. Facilitar la navegación dentro de videos (Identificar acciones en videos largos, sin la necesidad de ver todo el video)
#
# Entre otros
#
# Además, el análisis de videos nos permite poder analizar en un mismo momento información multimodal (imágenes, audio, texto)

# %% [markdown]
# 3. What is action classification?

# %% [markdown]
# Es el desafío de identificar en un video las acciones que se están realizando a lo largo del mismo.

# %% [markdown]
# 4. Mention and describe the temporal sampling used in this tutorial

# %% [markdown]
# El sampleo temporal utilizado en este tutorial fue el denominado sampleo uniforme. Este método permite obtener N frames de un video, independientemente de su duración, dividiéndolo proporcionalmente en N segmentos y extrayendo un frame representativo de cada uno. Así, se logra la misma cantidad de frames para videos de distinta duración.

# %% [markdown]
# 5. What is the temporal pooling followed in this lab? What are the problems with it?

# %% [markdown]
# En la implementación de VideoCNN, al final del paso forward se tiene:
#
# ```python
# # unflatten output of cnn
# out = out.view((-1, self.num_segments) + out.size()[1:])
# # average pooling of representations
# out = torch.mean(out, dim = 1)
# ```
#
# Al pasar un batch de 40 videos, cada uno con 5 frames, la línea out.view(...) produce un tensor de dimensión (40, 5, 512). Cada uno de los 5 frames de cada video queda representado por su vector de características proveniente de la ResNet.
#
# Luego, torch.mean(out, dim=1) promedia las representaciones de los 5 frames de cada video, reduciendo la dimensionalidad a (40, 512). Es decir, cada video queda representado por un único vector promedio.
#
# Este promediado, sin embargo, genera un problema importante. Se pierde la temporalidad de los eventos, ya que todos los frames contribuyen por igual sin importar su orden o relevancia. Un evento clave presente en un solo frame puede diluirse al promediarse junto con frames menos informativos, dificultando que el modelo distinga su importancia relativa.

# %% [markdown]
# 6. Train and evaluate the model with 4 frames per video instead of 8 frames. How does the model performance be affected? Note: Use code of section 6 to show the training graph.

# %% [markdown]
# **Se utilizó 2 frames en vez de 3 frames, ya que el ejercicio del laboratorio se había realizado con 5 frames. Por lo tanto, para ejemplificar mejor la diferencia de entrenamiento, se eligió entrenar con 2 frames.**

# %%
## Write the code here ...
num_frames = 2

dataset_train = VideoDataset('/content/train', num_frames, transform_train)
dataset_val = VideoDataset('/content/val', num_frames, transform_val)

# %%
num_classes = len(dataset_train.list_classes)
model = VideoRNN(num_classes, num_frames)

# %%
num_epochs = 3

device = torch.device("cuda")
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %%
batch_size = 40

trainloader = torch.utils.data.DataLoader(dataset_train, batch_size=batch_size, shuffle=True)
testloader = torch.utils.data.DataLoader(dataset_val, batch_size=batch_size, shuffle=False)

dataloaders={'train': trainloader, 'val':testloader}
dataset_sizes = {'train': len(dataset_train), 'val': len(dataset_val)}

# %%
def train_model(model, criterion, optimizer, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    dict_acc = {'train': [], 'val': []}
    dict_loss = {'train': [], 'val': []}
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0
            num_elem = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    preds = torch.argmax(outputs, dim = 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                num_elem += inputs.size(0)

            epoch_loss = running_loss / num_elem
            epoch_acc = running_corrects.double() / num_elem

            dict_acc[phase].append(epoch_acc)
            dict_loss[phase].append(epoch_loss)
            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, dict_acc, dict_loss

# %%
model, dict_acc, dict_loss = train_model(model, criterion, optimizer, num_epochs=num_epochs)
# Out:
# Epoch 0/2
# ----------
# train Loss: 2.3345 Acc: 0.1861
# val Loss: 2.2034 Acc: 0.2557
#
# Epoch 1/2
# ----------
# train Loss: 2.0645 Acc: 0.3892
# val Loss: 1.9108 Acc: 0.4557
#
# Epoch 2/2
# ----------
# train Loss: 1.7160 Acc: 0.5645
# val Loss: 1.5588 Acc: 0.5902
#
# Training complete in 1m 9s
# Best val Acc: 0.590164

# %%
epochs = list(range(num_epochs))
plt.plot(epochs, parse_data(dict_acc['train']), 'r', label='Train')
plt.plot(epochs, parse_data(dict_acc['val']), 'b', label='Val')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %% [markdown]
# Al disminuir la cantidad de frames a samplear desde los videos, se aprecia una disminución importante en el accuracy del conjunto de validación. En específico, se ve una disminución de casi 15 puntos porcentuales, pasando de un desempeño de ~65% a un 50%.
