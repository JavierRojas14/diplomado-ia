# %% [markdown]
# # **Diplomado IA: Inteligencia Artificial II - Parte 2**. <br> Práctico 32: Aprendizaje Incremental y  Olvido Catastrófico
# ---
# ---
#
# ## **Profesores:**
# - Alain Raymond
#
# ### **Ayudante**:
#
# ---
#
# El siguiente práctico se debe realizar de forma individual. El formato de entregar es el **archivo .ipynb con todas las celdas ejecutadas**. Las secciones donde se planteen preguntas de forma explícita, deben ser respondida en celdas de texto, y no se aceptará solo el _output_ de una celda de código como respuesta.
#
# **Nombre alumno:**
#
# El siguiente práctico contendrá 1 o más actividades a realizar. Algunas actividades corresponderán a escribir código y otras a responder preguntas.
#
# Antes de responder, se recomienda **fuertemente** revisar las secciones previas donde se desarrollan los ejemplos, dado que algunas de las actividades pueden ser completadas reutilizando el mismo código.
#
#
# ---
# **IMPORTANTE:** habrá un bonus de 1 décima para todos aquellos alumnos/as que muestren buen orden en sus respuestas (esto aplica a legibilidad de código, buena redacción, formalidad, organización del jupyter notebook, seguimiento de instrucciones, etc). El criterio lo pondrá cada ayudante corrector. La nota máxima obtenible en el laboratorio es 7.0

# %% [markdown]
# # Introducción
#
# Este laboratorio se basó en una serie de Notebooks del grupo [Continual AI](https://www.continualai.org/), la cual es una comunidad abierta que busca desarrollar investigación y divulgación sobre Aprendizaje Continuo.
#
# Tal como vimos en clases, el aprendizaje incremental estudia modelos y métodos que permitan un proceso de aprendizaje continuo de varias tareas diferentes.
#
# En este laboratorio vamos a ver cómo se comportan diferentes métodos simples en una secuencia de tareas muy utilizadas para comparación entre métodos.

# %% [markdown]
# Lo primero que tenemos que hacer es verificar cómo están los niveles de memoria y disco. Luego verificamos si tenemos acceso a GPU.

# %%
# !free -m
# !df -h
# !nvidia-smi
# Out:
#                total        used        free      shared  buff/cache   available
# Mem:           12975        1118       11409           2         716       11857
# Swap:              0           0           0
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         113G   48G   65G  43% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.7G     0  5.7G   0% /dev/shm
# /dev/root       2.0G  1.3G  696M  65% /usr/sbin/docker-init
# tmpfs           6.4G   84K  6.4G   1% /var/colab
# /dev/sda1       119G   53G   67G  45% /kaggle/input
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware
# Sat Sep 12 00:51:50 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   57C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# Cargamos todas las librerias que vamos a utilizar durante este laboratorio:

# %%
import random
import torch
import torch.nn as nn
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Modelo

# %%
# switch to False to use CPU
use_cuda = True

use_cuda = use_cuda and torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
torch.manual_seed(1);

# %% [markdown]
# El modelo consiste en 2 capas convolucionales más dos capas lineales, se agregan capas de max pooling y funciones de activación.
#
# El modelo utilizado es simple ya que la motivación no es lograr los mejores resultados en cada tarea, sino que nos permite reflejar lo que ocurre cuando no tenemos precauciones al entrenar una nueva tarea.

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.conv2_drop = nn.Dropout2d()
        self.fc1 = nn.Linear(320, 50)
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        x = x.view(-1, 320)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return x

# %% [markdown]
# # Dataset
#
# En este laboratorio vamos a utilizar el dataset *MNIST* (LeCun, Yann, et al. "Gradient-based learning applied to document recognition." Proceedings of the IEEE 86.11 (1998): 2278-2324.). Este dataset consiste en 60.000 imágenes de 28x28 pixeles, y cada una es una imagen de un dígito del 0 al 9 escrita a mano. Es decir, tiene 10 clases diferentes (una por dígito).
#
# Por simplicidad vamos a utilizar las funciones de descarga de Continual AI, ya que nos va a facilitar la creación de nuevas tareas.

# %%
# !git clone https://github.com/ContinualAI/colab.git continualai/colab
# Out:
# fatal: destination path 'continualai/colab' already exists and is not an empty directory.

# %% [markdown]
# Descargamos el dataset en nuestro entorno de colab

# %%
from os import path
import gzip
import pickle
import numpy as np

filename = [
    ["training_images", "train-images-idx3-ubyte.gz"],
    ["test_images", "t10k-images-idx3-ubyte.gz"],
    ["training_labels", "train-labels-idx1-ubyte.gz"],
    ["test_labels", "t10k-labels-idx1-ubyte.gz"]
]

# !wget https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz -q --show-progress
# !wget https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz -q --show-progress

# !wget https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz -q --show-progress
# !wget https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz -q --show-progress

def save_mnist():
    mnist = {}
    for name in filename[:2]:
        with gzip.open(name[1], 'rb') as f:
            tmp = np.frombuffer(f.read(), np.uint8, offset=16)
            mnist[name[0]] = tmp.reshape(-1, 1, 28, 28).astype(np.float32) / 255
    for name in filename[-2:]:
        with gzip.open(name[1], 'rb') as f:
            mnist[name[0]] = np.frombuffer(f.read(), np.uint8, offset=8)
    with open("mnist.pkl", 'wb') as f:
        pickle.dump(mnist, f)
    print("Save complete.")

save_mnist()
# Out:
# train-images-idx3-u 100%[===================>]   9.45M  18.0MB/s    in 0.5s
# train-labels-idx1-u 100%[===================>]  28.20K  --.-KB/s    in 0.07s
# t10k-images-idx3-ub 100%[===================>]   1.57M  4.02MB/s    in 0.4s
# t10k-labels-idx1-ub 100%[===================>]   4.44K  --.-KB/s    in 0s
# Save complete.

# %%
from continualai.colab.scripts import mnist
mnist.init()
# Out:
# Files already downloaded!

# %% [markdown]
# Luego lo cargamos a memoria.
#
# El dataset que estamos utilizando es muy simple, ideal para hacer pruebas de concepto, ya que tiene varias imagenes pequeñas. Al ser pequeñas, estas se pueden cargar en memoria completamente, lo que acelera bastante el proceso de entrenamiento.
#
# Lo bueno de probar estos métodos en pequeños dataset es que nos permite validar nuestra propuesta antes de consumir horas o días de computo probando en otra secuencia de tareas. Pero una vez que validamos las ideas, podemos probar los mismos métodos en otras tareas.

# %%
x_train, y_train, x_test, y_test = mnist.load()

# %%
f, axarr = plt.subplots(2,2)
axarr[0,0].imshow(x_train[1, 0], cmap="gray")
axarr[0,1].imshow(x_train[2, 0], cmap="gray")
axarr[1,0].imshow(x_train[3, 0], cmap="gray")
axarr[1,1].imshow(x_train[4, 0], cmap="gray")
np.vectorize(lambda ax:ax.axis('off'))(axarr);

# %% [markdown]
# ## Permuted MNIST
#
# Esta secuencia de tareas consiste en tomar cada imagen del set original del dataset MNIST, y realizar una permutación de los pixeles para que refleje otros patrones en la imagen.
#
# Cada tarea que queremos agregar es una nueva permutación que se hace a cada una de las imágenes. Por ejemplo, una nueva tarea puede ser mover todos los píxeles uno a la derecha. Pero lo que se hace normalmente es que cada tarea es una permutación aleatoria de todos los píxeles, buscando generar patrones únicos en cada tarea.

# %%
def permute_mnist(mnist, seed):
    """ Given the training set, permute pixels of each img the same way. """

    np.random.seed(seed)
    print("starting permutation...")
    h = w = 28
    perm_inds = list(range(h*w))
    np.random.shuffle(perm_inds)
    # print(perm_inds)
    perm_mnist = []
    for set in mnist:
        num_img = set.shape[0]
        flat_set = set.reshape(num_img, w * h)
        perm_mnist.append(flat_set[:, perm_inds].reshape(num_img, 1, w, h))
    print("done.")
    return perm_mnist

# %%
x_train2, x_test2 = permute_mnist([x_train, x_test], 0)
f, axarr = plt.subplots(1,2)
axarr[0].imshow(x_train[1, 0], cmap="gray")
axarr[1].imshow(x_train2[2, 0], cmap="gray")
np.vectorize(lambda ax:ax.axis('off'))(axarr);
# Out:
# starting permutation...
# done.

# %%
x_train2, x_test2 = permute_mnist([x_train, x_test], 5)
f, axarr = plt.subplots(1,2)
axarr[0].imshow(x_train[1, 0], cmap="gray")
axarr[1].imshow(x_train2[2, 0], cmap="gray")
np.vectorize(lambda ax:ax.axis('off'))(axarr);
# Out:
# starting permutation...
# done.

# %% [markdown]
# # Entrenamiento
#
# Tal como en laboratorios anteriores, tenemos dos funciones que nos ayudan a entrenar e ir verificando cómo van los entrenamientos de nuestro modelo.
#
# **train**: Es la encargada de entrenar el modelo con los datos que le entregamos. Estos deben ser de la tarea actual.
#
# **test**: Nos devuelve el accuracy logrado por el modelo con los datos que le entregamos.

# %%
def train(model, device, x_train, y_train, optimizer, epoch):
    model.train()

    for start in range(0, len(y_train)-1, 256):
        end = start + 256
        x, y = torch.from_numpy(x_train[start:end]), torch.from_numpy(y_train[start:end]).long()
        x, y = x.to(device), y.to(device)

        optimizer.zero_grad()

        output = model(x)
        loss = F.cross_entropy(output, y)
        loss.backward()
        optimizer.step()
        #print(loss.item())
    print('Train Epoch: {} \tLoss: {:.6f}'.format(epoch, loss.item()))

def test(model, device, x_test, y_test):
    model.eval()
    test_loss = 0
    correct = 0
    for start in range(0, len(y_test)-1, 256):
       end = start + 256
       with torch.no_grad():
          x, y = torch.from_numpy(x_test[start:end]), torch.from_numpy(y_test[start:end]).long()
          x, y = x.to(device), y.to(device)
          output = model(x)
          test_loss += F.cross_entropy(output, y).item() # sum up batch loss
          pred = output.max(1, keepdim=True)[1] # get the index of the max logit
          correct += pred.eq(y.view_as(pred)).sum().item()

    test_loss /= len(y_test)
    print('Test set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(y_test),
        100. * correct / len(y_test)))
    return 100. * correct / len(y_test)

# %% [markdown]
# Es importante inicializar el modelo cada vez que queramos entrenar una nueva secuencia, ya que si no lo hacemos estamos partiendo con un modelo que ya tiene información de alguna tarea en sus pesos.

# %%
model = Net().to(device)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %%
for epoch in range(1, 5):
   train(model, device, x_train, y_train, optimizer, epoch)
   test(model, device, x_test, y_test)
# Out:
# Train Epoch: 1 	Loss: 0.754889
# Test set: Average loss: 0.0013, Accuracy: 9019/10000 (90%)
#
# Train Epoch: 2 	Loss: 0.496502
# Test set: Average loss: 0.0007, Accuracy: 9431/10000 (94%)
#
# Train Epoch: 3 	Loss: 0.456321
# Test set: Average loss: 0.0006, Accuracy: 9565/10000 (96%)
#
# Train Epoch: 4 	Loss: 0.473526
# Test set: Average loss: 0.0005, Accuracy: 9625/10000 (96%)

# %% [markdown]
# Con los resultados anteriores, podemos ver que el modelo logró un muy buen rendimiento en la tarea con los datos original. Lo mejor, es que no necesita una gran cantidad de épocas para alcanzar esos resultados.

# %% [markdown]
# ## Olvido Catastrófico
#
# El mayor problema que tiene el aprender tareas de manera secuencial es lo que se conoce como Olvido Catastrófico, donde al entrenar una nueva tarea, el rendimiento alcanzado en tareas anteriores se ve fuertemente afectado.
#
# Primero veamos el accuracy que alcanza un modelo en dos tareas, cuando fue entrenado solo en la primera:

# %%
print("Testing on the first task:")
test(model, device, x_test, y_test)

print("Testing on the second task:")
test(model, device, x_test2, y_test);
# Out:
# Testing on the first task:
# Test set: Average loss: 0.0005, Accuracy: 9625/10000 (96%)
#
# Testing on the second task:
# Test set: Average loss: 0.0099, Accuracy: 1005/10000 (10%)

# %% [markdown]
# Como era esperado, a nuestro modelo no le va bien en una tarea en la cual no ha sido entrenado. Esto se refleja más todavía cuando las imágenes entre las tareas son bien diferentes.
#
# Debido a lo anterior, es necesario entrenar el modelo en este nuevo dataset para que adquiera los conocimientos necesarios, y se pueda desempeñar de manera correcta en esta nueva tarea.

# %%
for epoch in range(1, 4):
  train(model, device, x_train2, y_train, optimizer, epoch)
  test(model, device, x_test2, y_test)
# Out:
# Train Epoch: 1 	Loss: 1.234940
# Test set: Average loss: 0.0031, Accuracy: 7536/10000 (75%)
#
# Train Epoch: 2 	Loss: 0.991616
# Test set: Average loss: 0.0022, Accuracy: 8254/10000 (83%)
#
# Train Epoch: 3 	Loss: 0.970262
# Test set: Average loss: 0.0017, Accuracy: 8630/10000 (86%)

# %%
print("Testing on the first task:")
test(model, device, x_test, y_test)

print("Testing on the second task:")
test(model, device, x_test2, y_test);
# Out:
# Testing on the first task:
# Test set: Average loss: 0.0171, Accuracy: 3018/10000 (30%)
#
# Testing on the second task:
# Test set: Average loss: 0.0017, Accuracy: 8630/10000 (86%)

# %% [markdown]
# Pero tal como vimos en clases, se produce el problema de olvido catastrófico, donde obtenemos un buen rendimiento en la segunda tarea pero en la primera tarea olvidamos casi todo lo aprendido.

# %% [markdown]
# # Estrategias de Aprendizaje Continuo
#
# En este laboratorio vamos a comprobar el rendimiento de 3 metodos diferentes:
#
# 1.   Naive: Entrenamiento sin ningun tipo de metodo preocupado de alivianar el problema del olvido
# 2.   Rehearsal: Tener una memoria con datos de tareas pasadas
# 3.   Elastic Weight Consolidation (EWC): Uno de los metodo que vimos en clases
#
# Primero vamos a crear las diferentes tareas que vamos a utilizar. La variable *num_tasks* es la encargada de determinar la cantidad de tareas que vamos a probar, y *num_epoch* por cuantas iteraciones vamos a entrenar cada tarea.

# %%
num_tasks = 4
num_epoch = 3
tasks = []
for i in range(num_tasks):
    if i > 0:
        train_x, test_x = permute_mnist([x_train, x_test], i)
        task = [(train_x, y_train), (test_x, y_test)]
    else:
        task = [(x_train, y_train), (x_test, y_test)]

    tasks.append(task)
# Out:
# starting permutation...
# done.
# starting permutation...
# done.
# starting permutation...
# done.

# %% [markdown]
# ## Naive Strategy
#
# A modo de *baseline*, vamos a entrenar el modelo con la estrategia más simple.  Esta consiste en entrenar de manera secuencial todas las tareas sin ningún tipo de estrategia contra el olvido.

# %%
model = Net().to(device)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %%
naive_accs = []

for id, task in enumerate(tasks):
    avg_acc = 0
    print("Training on task: ", id)

    (x_train, y_train), _ = task

    for epoch in range(1, num_epoch):
        train(model, device, x_train, y_train, optimizer, epoch)

    for id_test, task in enumerate(tasks):
        print("Testing on task: ", id_test)
        _, (x_test, y_test) = task
        acc = test(model, device, x_test, y_test)
        avg_acc = avg_acc + acc

    naive_accs.append(avg_acc / len(tasks))
    print("Avg acc: ", avg_acc / len(tasks))
# Out:
# Training on task:  0
# Train Epoch: 1 	Loss: 0.677050
# Train Epoch: 2 	Loss: 0.524906
# Testing on task:  0
# Test set: Average loss: 0.0007, Accuracy: 9448/10000 (94%)
#
# Testing on task:  1
# Test set: Average loss: 0.0112, Accuracy: 604/10000 (6%)
#
# Testing on task:  2
# Test set: Average loss: 0.0098, Accuracy: 1393/10000 (14%)
#
# Testing on task:  3
# Test set: Average loss: 0.0109, Accuracy: 934/10000 (9%)
#
# Avg acc:  30.947500000000005
# Training on task:  1
# Train Epoch: 1 	Loss: 1.827685
# Train Epoch: 2 	Loss: 1.431625
# Testing on task:  0
# Test set: Average loss: 0.0227, Accuracy: 2178/10000 (22%)
#
# Testing on task:  1
# Test set: Average loss: 0.0027, Accuracy: 8012/10000 (80%)
#
# Testing on task:  2
# Test set: Average loss: 0.0124, Accuracy: 1093/10000 (11%)
#
# Testing on task:  3
# Test set: Average loss: 0.0116, Accuracy: 1155/10000 (12%)
#
# Avg acc:  31.095000000000002
# Training on task:  2
# Train Epoch: 1 	Loss: 1.669508
# Train Epoch: 2 	Loss: 1.351092
# Testing on task:  0
# Test set: Average loss: 0.0221, Accuracy: 2378/10000 (24%)
#
# Testing on task:  1
# Test set: Average loss: 0.0080, Accuracy: 3243/10000 (32%)
#
# Testing on task:  2
# Test set: Average loss: 0.0025, Accuracy: 8135/10000 (81%)
#
# Testing on task:  3
# Test set: Average loss: 0.0121, Accuracy: 1157/10000 (12%)
#
# Avg acc:  37.2825
# Training on task:  3
# Train Epoch: 1 	Loss: 1.375231
# Train Epoch: 2 	Loss: 0.989451
# Testing on task:  0
# Test set: Average loss: 0.0187, Accuracy: 1719/10000 (17%)
#
# Testing on task:  1
# Test set: Average loss: 0.0094, Accuracy: 2047/10000 (20%)
#
# Testing on task:  2
# Test set: Average loss: 0.0068, Accuracy: 3823/10000 (38%)
#
# Testing on task:  3
# Test set: Average loss: 0.0023, Accuracy: 8211/10000 (82%)
#
# Avg acc:  39.5

# %% [markdown]
# ### Actividad Practica 1
#
# - ¿Afecta el orden de las tareas? Por ejemplo si invertimos el orden de las tareas, entrenando la última, luego la penúltima, se ven resultados diferentes?
# - ¿Cómo afecta el rendimiento promedio de este método cuando agregamos más tareas?

# %% [markdown]
# ### Pregunta 1

# %%
model = Net().to(device)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %%
# Experimentos aquí #
tasks_aleatorias = random.sample(tasks, len(tasks))

shuffled_accs = []

for id, task in enumerate(tasks_aleatorias):
    avg_acc = 0
    print("Training on task: ", id)

    (x_train, y_train), _ = task

    for epoch in range(1, num_epoch):
        train(model, device, x_train, y_train, optimizer, epoch)

    for id_test, task in enumerate(tasks_aleatorias):
        print("Testing on task: ", id_test)
        _, (x_test, y_test) = task
        acc = test(model, device, x_test, y_test)
        avg_acc = avg_acc + acc

    shuffled_accs.append(avg_acc / len(tasks_aleatorias))
    print("Avg acc: ", avg_acc / len(tasks_aleatorias))
# Out:
# Training on task:  0
# Train Epoch: 1 	Loss: 0.899424
# Train Epoch: 2 	Loss: 0.421911
# Testing on task:  0
# Test set: Average loss: 0.0007, Accuracy: 9429/10000 (94%)
#
# Testing on task:  1
# Test set: Average loss: 0.0099, Accuracy: 1317/10000 (13%)
#
# Testing on task:  2
# Test set: Average loss: 0.0116, Accuracy: 914/10000 (9%)
#
# Testing on task:  3
# Test set: Average loss: 0.0117, Accuracy: 547/10000 (5%)
#
# Avg acc:  30.517500000000002
# Training on task:  1
# Train Epoch: 1 	Loss: 1.279377
# Train Epoch: 2 	Loss: 0.954497
# Testing on task:  0
# Test set: Average loss: 0.0179, Accuracy: 3907/10000 (39%)
#
# Testing on task:  1
# Test set: Average loss: 0.0021, Accuracy: 8416/10000 (84%)
#
# Testing on task:  2
# Test set: Average loss: 0.0119, Accuracy: 1119/10000 (11%)
#
# Testing on task:  3
# Test set: Average loss: 0.0134, Accuracy: 965/10000 (10%)
#
# Avg acc:  36.0175
# Training on task:  2
# Train Epoch: 1 	Loss: 1.341697
# Train Epoch: 2 	Loss: 1.049275
# Testing on task:  0
# Test set: Average loss: 0.0184, Accuracy: 1738/10000 (17%)
#
# Testing on task:  1
# Test set: Average loss: 0.0065, Accuracy: 3883/10000 (39%)
#
# Testing on task:  2
# Test set: Average loss: 0.0020, Accuracy: 8478/10000 (85%)
#
# Testing on task:  3
# Test set: Average loss: 0.0114, Accuracy: 1292/10000 (13%)
#
# Avg acc:  38.4775
# Training on task:  3
# Train Epoch: 1 	Loss: 1.534464
# Train Epoch: 2 	Loss: 1.325157
# Testing on task:  0
# Test set: Average loss: 0.0133, Accuracy: 1927/10000 (19%)
#
# Testing on task:  1
# Test set: Average loss: 0.0107, Accuracy: 1360/10000 (14%)
#
# Testing on task:  2
# Test set: Average loss: 0.0082, Accuracy: 2616/10000 (26%)
#
# Testing on task:  3
# Test set: Average loss: 0.0026, Accuracy: 8125/10000 (81%)
#
# Avg acc:  35.07

# %% [markdown]
# Modificar el orden de entrenamiento de las tareas mantiene los resultados vistos previamente. O sea, a pesar de modificar el orden de las tareas, el olvido catastrófico perdura.

# %% [markdown]
# ### Pregunta 2

# %% [markdown]
# ### 6 tareas distintas

# %%
num_tasks = 6
num_epoch = 3
tasks = []
for i in range(num_tasks):
    if i > 0:
        train_x, test_x = permute_mnist([x_train, x_test], i)
        task = [(train_x, y_train), (test_x, y_test)]
    else:
        task = [(x_train, y_train), (x_test, y_test)]

    tasks.append(task)
# Out:
# starting permutation...
# done.
# starting permutation...
# done.
# starting permutation...
# done.
# starting permutation...
# done.
# starting permutation...
# done.

# %%
model = Net().to(device)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %%
accs = []

for id, task in enumerate(tasks):
    avg_acc = 0
    print("Training on task: ", id)

    (x_train, y_train), _ = task

    for epoch in range(1, num_epoch):
        train(model, device, x_train, y_train, optimizer, epoch)

    for id_test, task in enumerate(tasks):
        print("Testing on task: ", id_test)
        _, (x_test, y_test) = task
        acc = test(model, device, x_test, y_test)
        avg_acc = avg_acc + acc

    accs.append(avg_acc / len(tasks))
    print("Avg acc: ", avg_acc / len(tasks))
# Out:
# Training on task:  0
# Train Epoch: 1 	Loss: 2.171636
# Train Epoch: 2 	Loss: 1.488748
# Testing on task:  0
# Test set: Average loss: 0.0029, Accuracy: 7940/10000 (79%)
#
# Testing on task:  1
# Test set: Average loss: 0.0133, Accuracy: 875/10000 (9%)
#
# Testing on task:  2
# Test set: Average loss: 0.0121, Accuracy: 1045/10000 (10%)
#
# Testing on task:  3
# Test set: Average loss: 0.0126, Accuracy: 792/10000 (8%)
#
# Testing on task:  4
# Test set: Average loss: 0.0123, Accuracy: 801/10000 (8%)
#
# Testing on task:  5
# Test set: Average loss: 0.0112, Accuracy: 851/10000 (9%)
#
# Avg acc:  20.50666666666667
# Training on task:  1
# Train Epoch: 1 	Loss: 1.445801
# Train Epoch: 2 	Loss: 1.100954
# Testing on task:  0
# Test set: Average loss: 0.0070, Accuracy: 3425/10000 (34%)
#
# Testing on task:  1
# Test set: Average loss: 0.0021, Accuracy: 8403/10000 (84%)
#
# Testing on task:  2
# Test set: Average loss: 0.0105, Accuracy: 1637/10000 (16%)
#
# Testing on task:  3
# Test set: Average loss: 0.0147, Accuracy: 814/10000 (8%)
#
# Testing on task:  4
# Test set: Average loss: 0.0122, Accuracy: 952/10000 (10%)
#
# Testing on task:  5
# Test set: Average loss: 0.0112, Accuracy: 1179/10000 (12%)
#
# Avg acc:  27.350000000000005
# Training on task:  2
# Train Epoch: 1 	Loss: 1.362456
# Train Epoch: 2 	Loss: 1.029533
# Testing on task:  0
# Test set: Average loss: 0.0088, Accuracy: 2300/10000 (23%)
#
# Testing on task:  1
# Test set: Average loss: 0.0073, Accuracy: 3387/10000 (34%)
#
# Testing on task:  2
# Test set: Average loss: 0.0019, Accuracy: 8543/10000 (85%)
#
# Testing on task:  3
# Test set: Average loss: 0.0122, Accuracy: 1307/10000 (13%)
#
# Testing on task:  4
# Test set: Average loss: 0.0115, Accuracy: 912/10000 (9%)
#
# Testing on task:  5
# Test set: Average loss: 0.0130, Accuracy: 671/10000 (7%)
#
# Avg acc:  28.533333333333335
# Training on task:  3
# Train Epoch: 1 	Loss: 1.163576
# Train Epoch: 2 	Loss: 1.029021
# Testing on task:  0
# Test set: Average loss: 0.0111, Accuracy: 1358/10000 (14%)
#
# Testing on task:  1
# Test set: Average loss: 0.0128, Accuracy: 997/10000 (10%)
#
# Testing on task:  2
# Test set: Average loss: 0.0095, Accuracy: 2485/10000 (25%)
#
# Testing on task:  3
# Test set: Average loss: 0.0020, Accuracy: 8443/10000 (84%)
#
# Testing on task:  4
# Test set: Average loss: 0.0136, Accuracy: 1326/10000 (13%)
#
# Testing on task:  5
# Test set: Average loss: 0.0125, Accuracy: 662/10000 (7%)
#
# Avg acc:  25.451666666666668
# Training on task:  4
# Train Epoch: 1 	Loss: 1.378601
# Train Epoch: 2 	Loss: 1.381967
# Testing on task:  0
# Test set: Average loss: 0.0102, Accuracy: 1183/10000 (12%)
#
# Testing on task:  1
# Test set: Average loss: 0.0123, Accuracy: 827/10000 (8%)
#
# Testing on task:  2
# Test set: Average loss: 0.0090, Accuracy: 1796/10000 (18%)
#
# Testing on task:  3
# Test set: Average loss: 0.0067, Accuracy: 3849/10000 (38%)
#
# Testing on task:  4
# Test set: Average loss: 0.0024, Accuracy: 8243/10000 (82%)
#
# Testing on task:  5
# Test set: Average loss: 0.0109, Accuracy: 847/10000 (8%)
#
# Avg acc:  27.908333333333335
# Training on task:  5
# Train Epoch: 1 	Loss: 1.680300
# Train Epoch: 2 	Loss: 1.313580
# Testing on task:  0
# Test set: Average loss: 0.0101, Accuracy: 1241/10000 (12%)
#
# Testing on task:  1
# Test set: Average loss: 0.0114, Accuracy: 839/10000 (8%)
#
# Testing on task:  2
# Test set: Average loss: 0.0105, Accuracy: 1126/10000 (11%)
#
# Testing on task:  3
# Test set: Average loss: 0.0098, Accuracy: 1571/10000 (16%)
#
# Testing on task:  4
# Test set: Average loss: 0.0074, Accuracy: 3313/10000 (33%)
#
# Testing on task:  5
# Test set: Average loss: 0.0025, Accuracy: 8116/10000 (81%)
#
# Avg acc:  27.01

# %% [markdown]
# ### 10 tareas distintas

# %%
num_tasks = 10
num_epoch = 3
tasks = []
for i in range(num_tasks):
    if i > 0:
        train_x, test_x = permute_mnist([x_train, x_test], i)
        task = [(train_x, y_train), (test_x, y_test)]
    else:
        task = [(x_train, y_train), (x_test, y_test)]

    tasks.append(task)
# Out:
# starting permutation...
# done.
# starting permutation...
# done.
# starting permutation...
# done.
# starting permutation...
# done.
# starting permutation...
# done.
# starting permutation...
# done.
# starting permutation...
# done.
# starting permutation...
# done.
# starting permutation...
# done.

# %%
model = Net().to(device)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %%
accs = []

for id, task in enumerate(tasks):
    avg_acc = 0
    print("Training on task: ", id)

    (x_train, y_train), _ = task

    for epoch in range(1, num_epoch):
        train(model, device, x_train, y_train, optimizer, epoch)

    for id_test, task in enumerate(tasks):
        print("Testing on task: ", id_test)
        _, (x_test, y_test) = task
        acc = test(model, device, x_test, y_test)
        avg_acc = avg_acc + acc

    accs.append(avg_acc / len(tasks))
    print("Avg acc: ", avg_acc / len(tasks))
# Out:
# Training on task:  0
# Train Epoch: 1 	Loss: 2.138597
# Train Epoch: 2 	Loss: 1.153260
# Testing on task:  0
# Test set: Average loss: 0.0028, Accuracy: 7945/10000 (79%)
#
# Testing on task:  1
# Test set: Average loss: 0.0107, Accuracy: 1099/10000 (11%)
#
# Testing on task:  2
# Test set: Average loss: 0.0108, Accuracy: 1343/10000 (13%)
#
# Testing on task:  3
# Test set: Average loss: 0.0116, Accuracy: 858/10000 (9%)
#
# Testing on task:  4
# Test set: Average loss: 0.0115, Accuracy: 1247/10000 (12%)
#
# Testing on task:  5
# Test set: Average loss: 0.0131, Accuracy: 872/10000 (9%)
#
# Testing on task:  6
# Test set: Average loss: 0.0113, Accuracy: 1044/10000 (10%)
#
# Testing on task:  7
# Test set: Average loss: 0.0112, Accuracy: 702/10000 (7%)
#
# Testing on task:  8
# Test set: Average loss: 0.0119, Accuracy: 846/10000 (8%)
#
# Testing on task:  9
# Test set: Average loss: 0.0111, Accuracy: 931/10000 (9%)
#
# Avg acc:  16.887000000000004
# Training on task:  1
# Train Epoch: 1 	Loss: 1.169227
# Train Epoch: 2 	Loss: 0.814687
# Testing on task:  0
# Test set: Average loss: 0.0070, Accuracy: 4136/10000 (41%)
#
# Testing on task:  1
# Test set: Average loss: 0.0019, Accuracy: 8525/10000 (85%)
#
# Testing on task:  2
# Test set: Average loss: 0.0110, Accuracy: 1690/10000 (17%)
#
# Testing on task:  3
# Test set: Average loss: 0.0143, Accuracy: 667/10000 (7%)
#
# Testing on task:  4
# Test set: Average loss: 0.0125, Accuracy: 1075/10000 (11%)
#
# Testing on task:  5
# Test set: Average loss: 0.0120, Accuracy: 1692/10000 (17%)
#
# Testing on task:  6
# Test set: Average loss: 0.0121, Accuracy: 1526/10000 (15%)
#
# Testing on task:  7
# Test set: Average loss: 0.0135, Accuracy: 1041/10000 (10%)
#
# Testing on task:  8
# Test set: Average loss: 0.0154, Accuracy: 866/10000 (9%)
#
# Testing on task:  9
# Test set: Average loss: 0.0123, Accuracy: 1401/10000 (14%)
#
# Avg acc:  22.618999999999993
# Training on task:  2
# Train Epoch: 1 	Loss: 1.351186
# Train Epoch: 2 	Loss: 0.934677
# Testing on task:  0
# Test set: Average loss: 0.0100, Accuracy: 1937/10000 (19%)
#
# Testing on task:  1
# Test set: Average loss: 0.0075, Accuracy: 3635/10000 (36%)
#
# Testing on task:  2
# Test set: Average loss: 0.0020, Accuracy: 8472/10000 (85%)
#
# Testing on task:  3
# Test set: Average loss: 0.0118, Accuracy: 1012/10000 (10%)
#
# Testing on task:  4
# Test set: Average loss: 0.0140, Accuracy: 1277/10000 (13%)
#
# Testing on task:  5
# Test set: Average loss: 0.0125, Accuracy: 725/10000 (7%)
#
# Testing on task:  6
# Test set: Average loss: 0.0133, Accuracy: 924/10000 (9%)
#
# Testing on task:  7
# Test set: Average loss: 0.0127, Accuracy: 812/10000 (8%)
#
# Testing on task:  8
# Test set: Average loss: 0.0117, Accuracy: 1148/10000 (11%)
#
# Testing on task:  9
# Test set: Average loss: 0.0111, Accuracy: 1214/10000 (12%)
#
# Avg acc:  21.156
# Training on task:  3
# Train Epoch: 1 	Loss: 1.875281
# Train Epoch: 2 	Loss: 1.261558
# Testing on task:  0
# Test set: Average loss: 0.0104, Accuracy: 1779/10000 (18%)
#
# Testing on task:  1
# Test set: Average loss: 0.0107, Accuracy: 1116/10000 (11%)
#
# Testing on task:  2
# Test set: Average loss: 0.0068, Accuracy: 4004/10000 (40%)
#
# Testing on task:  3
# Test set: Average loss: 0.0026, Accuracy: 8036/10000 (80%)
#
# Testing on task:  4
# Test set: Average loss: 0.0102, Accuracy: 1567/10000 (16%)
#
# Testing on task:  5
# Test set: Average loss: 0.0120, Accuracy: 729/10000 (7%)
#
# Testing on task:  6
# Test set: Average loss: 0.0130, Accuracy: 710/10000 (7%)
#
# Testing on task:  7
# Test set: Average loss: 0.0107, Accuracy: 1161/10000 (12%)
#
# Testing on task:  8
# Test set: Average loss: 0.0120, Accuracy: 1319/10000 (13%)
#
# Testing on task:  9
# Test set: Average loss: 0.0105, Accuracy: 1349/10000 (13%)
#
# Avg acc:  21.77
# Training on task:  4
# Train Epoch: 1 	Loss: 2.134300
# Train Epoch: 2 	Loss: 1.780136
# Testing on task:  0
# Test set: Average loss: 0.0114, Accuracy: 1530/10000 (15%)
#
# Testing on task:  1
# Test set: Average loss: 0.0085, Accuracy: 2417/10000 (24%)
#
# Testing on task:  2
# Test set: Average loss: 0.0093, Accuracy: 1877/10000 (19%)
#
# Testing on task:  3
# Test set: Average loss: 0.0106, Accuracy: 1018/10000 (10%)
#
# Testing on task:  4
# Test set: Average loss: 0.0039, Accuracy: 7071/10000 (71%)
#
# Testing on task:  5
# Test set: Average loss: 0.0104, Accuracy: 1608/10000 (16%)
#
# Testing on task:  6
# Test set: Average loss: 0.0113, Accuracy: 1287/10000 (13%)
#
# Testing on task:  7
# Test set: Average loss: 0.0108, Accuracy: 1144/10000 (11%)
#
# Testing on task:  8
# Test set: Average loss: 0.0101, Accuracy: 1427/10000 (14%)
#
# Testing on task:  9
# Test set: Average loss: 0.0105, Accuracy: 1136/10000 (11%)
#
# Avg acc:  20.514999999999997
# Training on task:  5
# Train Epoch: 1 	Loss: 1.738146
# Train Epoch: 2 	Loss: 1.592233
# Testing on task:  0
# Test set: Average loss: 0.0134, Accuracy: 965/10000 (10%)
#
# Testing on task:  1
# Test set: Average loss: 0.0094, Accuracy: 2221/10000 (22%)
#
# Testing on task:  2
# Test set: Average loss: 0.0132, Accuracy: 835/10000 (8%)
#
# Testing on task:  3
# Test set: Average loss: 0.0117, Accuracy: 847/10000 (8%)
#
# Testing on task:  4
# Test set: Average loss: 0.0107, Accuracy: 1467/10000 (15%)
#
# Testing on task:  5
# Test set: Average loss: 0.0027, Accuracy: 8015/10000 (80%)
#
# Testing on task:  6
# Test set: Average loss: 0.0110, Accuracy: 1169/10000 (12%)
#
# Testing on task:  7
# Test set: Average loss: 0.0133, Accuracy: 760/10000 (8%)
#
# Testing on task:  8
# Test set: Average loss: 0.0117, Accuracy: 902/10000 (9%)
#
# Testing on task:  9
# Test set: Average loss: 0.0112, Accuracy: 1029/10000 (10%)
#
# Avg acc:  18.21
# Training on task:  6
# Train Epoch: 1 	Loss: 2.303108
# Train Epoch: 2 	Loss: 1.680748
# Testing on task:  0
# Test set: Average loss: 0.0101, Accuracy: 1436/10000 (14%)
#
# Testing on task:  1
# Test set: Average loss: 0.0112, Accuracy: 971/10000 (10%)
#
# Testing on task:  2
# Test set: Average loss: 0.0115, Accuracy: 705/10000 (7%)
#
# Testing on task:  3
# Test set: Average loss: 0.0104, Accuracy: 1131/10000 (11%)
#
# Testing on task:  4
# Test set: Average loss: 0.0097, Accuracy: 1701/10000 (17%)
#
# Testing on task:  5
# Test set: Average loss: 0.0108, Accuracy: 1183/10000 (12%)
#
# Testing on task:  6
# Test set: Average loss: 0.0040, Accuracy: 7191/10000 (72%)
#
# Testing on task:  7
# Test set: Average loss: 0.0100, Accuracy: 1274/10000 (13%)
#
# Testing on task:  8
# Test set: Average loss: 0.0109, Accuracy: 731/10000 (7%)
#
# Testing on task:  9
# Test set: Average loss: 0.0117, Accuracy: 870/10000 (9%)
#
# Avg acc:  17.193
# Training on task:  7
# Train Epoch: 1 	Loss: 1.746128
# Train Epoch: 2 	Loss: 1.266106
# Testing on task:  0
# Test set: Average loss: 0.0114, Accuracy: 1178/10000 (12%)
#
# Testing on task:  1
# Test set: Average loss: 0.0120, Accuracy: 985/10000 (10%)
#
# Testing on task:  2
# Test set: Average loss: 0.0119, Accuracy: 800/10000 (8%)
#
# Testing on task:  3
# Test set: Average loss: 0.0125, Accuracy: 839/10000 (8%)
#
# Testing on task:  4
# Test set: Average loss: 0.0114, Accuracy: 809/10000 (8%)
#
# Testing on task:  5
# Test set: Average loss: 0.0118, Accuracy: 859/10000 (9%)
#
# Testing on task:  6
# Test set: Average loss: 0.0106, Accuracy: 1648/10000 (16%)
#
# Testing on task:  7
# Test set: Average loss: 0.0028, Accuracy: 7905/10000 (79%)
#
# Testing on task:  8
# Test set: Average loss: 0.0135, Accuracy: 583/10000 (6%)
#
# Testing on task:  9
# Test set: Average loss: 0.0109, Accuracy: 896/10000 (9%)
#
# Avg acc:  16.502000000000002
# Training on task:  8
# Train Epoch: 1 	Loss: 2.304289
# Train Epoch: 2 	Loss: 2.301726
# Testing on task:  0
# Test set: Average loss: 0.0092, Accuracy: 1135/10000 (11%)
#
# Testing on task:  1
# Test set: Average loss: 0.0092, Accuracy: 1143/10000 (11%)
#
# Testing on task:  2
# Test set: Average loss: 0.0092, Accuracy: 1136/10000 (11%)
#
# Testing on task:  3
# Test set: Average loss: 0.0092, Accuracy: 1154/10000 (12%)
#
# Testing on task:  4
# Test set: Average loss: 0.0092, Accuracy: 1135/10000 (11%)
#
# Testing on task:  5
# Test set: Average loss: 0.0092, Accuracy: 1135/10000 (11%)
#
# Testing on task:  6
# Test set: Average loss: 0.0092, Accuracy: 1133/10000 (11%)
#
# Testing on task:  7
# Test set: Average loss: 0.0092, Accuracy: 1135/10000 (11%)
#
# Testing on task:  8
# Test set: Average loss: 0.0092, Accuracy: 1144/10000 (11%)
#
# Testing on task:  9
# Test set: Average loss: 0.0092, Accuracy: 1135/10000 (11%)
#
# Avg acc:  11.384999999999998
# Training on task:  9
# Train Epoch: 1 	Loss: 2.303070
# Train Epoch: 2 	Loss: 2.306017
# Testing on task:  0
# Test set: Average loss: 0.0092, Accuracy: 1135/10000 (11%)
#
# Testing on task:  1
# Test set: Average loss: 0.0092, Accuracy: 1144/10000 (11%)
#
# Testing on task:  2
# Test set: Average loss: 0.0092, Accuracy: 1135/10000 (11%)
#
# Testing on task:  3
# Test set: Average loss: 0.0092, Accuracy: 1140/10000 (11%)
#
# Testing on task:  4
# Test set: Average loss: 0.0092, Accuracy: 1136/10000 (11%)
#
# Testing on task:  5
# Test set: Average loss: 0.0092, Accuracy: 1135/10000 (11%)
#
# Testing on task:  6
# Test set: Average loss: 0.0092, Accuracy: 1134/10000 (11%)
#
# Testing on task:  7
# Test set: Average loss: 0.0092, Accuracy: 1135/10000 (11%)
#
# Testing on task:  8
# Test set: Average loss: 0.0092, Accuracy: 1138/10000 (11%)
#
# Testing on task:  9
# Test set: Average loss: 0.0092, Accuracy: 1135/10000 (11%)
#
# Avg acc:  11.366999999999999

# %% [markdown]
# Al aumentar la cantidad de tareas, la métrica de Average Accuracy va disminuyendo. Los resultados obtenidos de los experimentos fueron:
#
# |Número de Tareas|Accuracy en Epoch 3 de la última tarea|
# |-----|-----|
# |4|35.07%|
# |6|27.01%|
# |10|11.37%|
#
# Por lo tanto, se ve una disminución drástica en el desempeño del modelo.

# %% [markdown]
# ## Rehearsal Strategy
#
# Una manera simple de no perder rendimiento en tareas pasadas es la de ir acumulando los datos en un gran dataset, de manera de siempre tener la distribución de los datos antiguos y nuevos disponible. Existen tres problemas con esto:
# * El costo computacional de entrenar el modelo con cada vez más datos
# * El costo en memoria, al ir guardando todos los datos aumenta
# * El costo en privacidad que tiene guardar estos datos
#
# Una alternativa a guardar todos los datos, es ir guardar un porcentaje de los datos de tareas anteriores, alivianando en parte los problemas mencionados. Pero cómo vamos a ver a continuación, existe un trade-off entre la cantidad de datos que estamos guardando y el rendimiento que podemos alcanzar.

# %%
def shuffle_in_unison(dataset, seed, in_place=False):
    """ Shuffle two (or more) list in unison. """

    np.random.seed(seed)
    rng_state = np.random.get_state()
    new_dataset = []
    for x in dataset:
        if in_place:
            np.random.shuffle(x)
        else:
            new_dataset.append(np.random.permutation(x))
        np.random.set_state(rng_state)

    if not in_place:
        return new_dataset

# %% [markdown]
# Luego tenemos que re-inicializar el modelo para no partir de una base previamente entrenada y tener una comparación más justa.

# %%
model = Net().to(device)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %%
rehe_accs = []
num_past_elem = 1000 #50000 -> Dataset total

for id, task in enumerate(tasks):
    avg_acc = 0
    print("Training on task: ", id)

    (x_train, y_train), _ = task

    # for previous task
    for i in range(id):
        (past_x_train, past_y_train), _ = tasks[i]
        idx = random.sample(list(range(len(past_y_train))), num_past_elem)
        x_train = np.concatenate((x_train, past_x_train[idx]))
        y_train = np.concatenate((y_train, past_y_train[idx]))

    x_train, y_train = shuffle_in_unison([x_train, y_train], 0)

    for epoch in range(1, num_epoch):
        train(model, device, x_train, y_train, optimizer, epoch)

    for id_test, task in enumerate(tasks):
        print("Testing on task: ", id_test)
        _, (x_test, y_test) = task
        acc = test(model, device, x_test, y_test)
        avg_acc = avg_acc + acc

    print("Avg acc: ", avg_acc / len(tasks))
    rehe_accs.append(avg_acc/len(tasks))
# Out:
# Training on task:  0
# Train Epoch: 1 	Loss: 1.893195
# Train Epoch: 2 	Loss: 0.935569
# Testing on task:  0
# Test set: Average loss: 0.0026, Accuracy: 8181/10000 (82%)
#
# Testing on task:  1
# Test set: Average loss: 0.0107, Accuracy: 1324/10000 (13%)
#
# Testing on task:  2
# Test set: Average loss: 0.0112, Accuracy: 1396/10000 (14%)
#
# Testing on task:  3
# Test set: Average loss: 0.0118, Accuracy: 1142/10000 (11%)
#
# Testing on task:  4
# Test set: Average loss: 0.0124, Accuracy: 1358/10000 (14%)
#
# Testing on task:  5
# Test set: Average loss: 0.0124, Accuracy: 1188/10000 (12%)
#
# Testing on task:  6
# Test set: Average loss: 0.0123, Accuracy: 961/10000 (10%)
#
# Testing on task:  7
# Test set: Average loss: 0.0127, Accuracy: 788/10000 (8%)
#
# Testing on task:  8
# Test set: Average loss: 0.0122, Accuracy: 777/10000 (8%)
#
# Testing on task:  9
# Test set: Average loss: 0.0127, Accuracy: 1003/10000 (10%)
#
# Avg acc:  18.118000000000002
# Training on task:  1
# Train Epoch: 1 	Loss: 0.944292
# Train Epoch: 2 	Loss: 0.728369
# Testing on task:  0
# Test set: Average loss: 0.0048, Accuracy: 5814/10000 (58%)
#
# Testing on task:  1
# Test set: Average loss: 0.0016, Accuracy: 8859/10000 (89%)
#
# Testing on task:  2
# Test set: Average loss: 0.0120, Accuracy: 1199/10000 (12%)
#
# Testing on task:  3
# Test set: Average loss: 0.0124, Accuracy: 1180/10000 (12%)
#
# Testing on task:  4
# Test set: Average loss: 0.0114, Accuracy: 1076/10000 (11%)
#
# Testing on task:  5
# Test set: Average loss: 0.0118, Accuracy: 1905/10000 (19%)
#
# Testing on task:  6
# Test set: Average loss: 0.0113, Accuracy: 1299/10000 (13%)
#
# Testing on task:  7
# Test set: Average loss: 0.0123, Accuracy: 976/10000 (10%)
#
# Testing on task:  8
# Test set: Average loss: 0.0130, Accuracy: 1346/10000 (13%)
#
# Testing on task:  9
# Test set: Average loss: 0.0115, Accuracy: 1199/10000 (12%)
#
# Avg acc:  24.853000000000005
# Training on task:  2
# Train Epoch: 1 	Loss: 0.671063
# Train Epoch: 2 	Loss: 0.444841
# Testing on task:  0
# Test set: Average loss: 0.0070, Accuracy: 3981/10000 (40%)
#
# Testing on task:  1
# Test set: Average loss: 0.0050, Accuracy: 5813/10000 (58%)
#
# Testing on task:  2
# Test set: Average loss: 0.0017, Accuracy: 8608/10000 (86%)
#
# Testing on task:  3
# Test set: Average loss: 0.0120, Accuracy: 891/10000 (9%)
#
# Testing on task:  4
# Test set: Average loss: 0.0114, Accuracy: 1380/10000 (14%)
#
# Testing on task:  5
# Test set: Average loss: 0.0129, Accuracy: 919/10000 (9%)
#
# Testing on task:  6
# Test set: Average loss: 0.0125, Accuracy: 1261/10000 (13%)
#
# Testing on task:  7
# Test set: Average loss: 0.0111, Accuracy: 1272/10000 (13%)
#
# Testing on task:  8
# Test set: Average loss: 0.0112, Accuracy: 1187/10000 (12%)
#
# Testing on task:  9
# Test set: Average loss: 0.0123, Accuracy: 1019/10000 (10%)
#
# Avg acc:  26.331
# Training on task:  3
# Train Epoch: 1 	Loss: 1.071843
# Train Epoch: 2 	Loss: 0.895511
# Testing on task:  0
# Test set: Average loss: 0.0078, Accuracy: 2768/10000 (28%)
#
# Testing on task:  1
# Test set: Average loss: 0.0069, Accuracy: 3647/10000 (36%)
#
# Testing on task:  2
# Test set: Average loss: 0.0055, Accuracy: 5317/10000 (53%)
#
# Testing on task:  3
# Test set: Average loss: 0.0019, Accuracy: 8707/10000 (87%)
#
# Testing on task:  4
# Test set: Average loss: 0.0101, Accuracy: 1191/10000 (12%)
#
# Testing on task:  5
# Test set: Average loss: 0.0107, Accuracy: 1502/10000 (15%)
#
# Testing on task:  6
# Test set: Average loss: 0.0118, Accuracy: 802/10000 (8%)
#
# Testing on task:  7
# Test set: Average loss: 0.0112, Accuracy: 857/10000 (9%)
#
# Testing on task:  8
# Test set: Average loss: 0.0098, Accuracy: 1153/10000 (12%)
#
# Testing on task:  9
# Test set: Average loss: 0.0106, Accuracy: 939/10000 (9%)
#
# Avg acc:  26.883
# Training on task:  4
# Train Epoch: 1 	Loss: 1.006583
# Train Epoch: 2 	Loss: 0.929682
# Testing on task:  0
# Test set: Average loss: 0.0079, Accuracy: 2684/10000 (27%)
#
# Testing on task:  1
# Test set: Average loss: 0.0075, Accuracy: 3319/10000 (33%)
#
# Testing on task:  2
# Test set: Average loss: 0.0075, Accuracy: 3151/10000 (32%)
#
# Testing on task:  3
# Test set: Average loss: 0.0052, Accuracy: 5927/10000 (59%)
#
# Testing on task:  4
# Test set: Average loss: 0.0019, Accuracy: 8624/10000 (86%)
#
# Testing on task:  5
# Test set: Average loss: 0.0108, Accuracy: 1125/10000 (11%)
#
# Testing on task:  6
# Test set: Average loss: 0.0103, Accuracy: 1177/10000 (12%)
#
# Testing on task:  7
# Test set: Average loss: 0.0106, Accuracy: 922/10000 (9%)
#
# Testing on task:  8
# Test set: Average loss: 0.0096, Accuracy: 1499/10000 (15%)
#
# Testing on task:  9
# Test set: Average loss: 0.0111, Accuracy: 800/10000 (8%)
#
# Avg acc:  29.228
# Training on task:  5
# Train Epoch: 1 	Loss: 1.163912
# Train Epoch: 2 	Loss: 1.032488
# Testing on task:  0
# Test set: Average loss: 0.0089, Accuracy: 1535/10000 (15%)
#
# Testing on task:  1
# Test set: Average loss: 0.0080, Accuracy: 2671/10000 (27%)
#
# Testing on task:  2
# Test set: Average loss: 0.0083, Accuracy: 2428/10000 (24%)
#
# Testing on task:  3
# Test set: Average loss: 0.0071, Accuracy: 4068/10000 (41%)
#
# Testing on task:  4
# Test set: Average loss: 0.0064, Accuracy: 4796/10000 (48%)
#
# Testing on task:  5
# Test set: Average loss: 0.0023, Accuracy: 8428/10000 (84%)
#
# Testing on task:  6
# Test set: Average loss: 0.0101, Accuracy: 1020/10000 (10%)
#
# Testing on task:  7
# Test set: Average loss: 0.0101, Accuracy: 850/10000 (8%)
#
# Testing on task:  8
# Test set: Average loss: 0.0092, Accuracy: 1409/10000 (14%)
#
# Testing on task:  9
# Test set: Average loss: 0.0097, Accuracy: 1195/10000 (12%)
#
# Avg acc:  28.4
# Training on task:  6
# Train Epoch: 1 	Loss: 1.448851
# Train Epoch: 2 	Loss: 1.123626
# Testing on task:  0
# Test set: Average loss: 0.0084, Accuracy: 2253/10000 (23%)
#
# Testing on task:  1
# Test set: Average loss: 0.0085, Accuracy: 2004/10000 (20%)
#
# Testing on task:  2
# Test set: Average loss: 0.0087, Accuracy: 1983/10000 (20%)
#
# Testing on task:  3
# Test set: Average loss: 0.0080, Accuracy: 2687/10000 (27%)
#
# Testing on task:  4
# Test set: Average loss: 0.0082, Accuracy: 2681/10000 (27%)
#
# Testing on task:  5
# Test set: Average loss: 0.0062, Accuracy: 4595/10000 (46%)
#
# Testing on task:  6
# Test set: Average loss: 0.0024, Accuracy: 8286/10000 (83%)
#
# Testing on task:  7
# Test set: Average loss: 0.0103, Accuracy: 872/10000 (9%)
#
# Testing on task:  8
# Test set: Average loss: 0.0100, Accuracy: 1122/10000 (11%)
#
# Testing on task:  9
# Test set: Average loss: 0.0101, Accuracy: 1010/10000 (10%)
#
# Avg acc:  27.493000000000002
# Training on task:  7
# Train Epoch: 1 	Loss: 1.397744
# Train Epoch: 2 	Loss: 1.117327
# Testing on task:  0
# Test set: Average loss: 0.0089, Accuracy: 1879/10000 (19%)
#
# Testing on task:  1
# Test set: Average loss: 0.0087, Accuracy: 2294/10000 (23%)
#
# Testing on task:  2
# Test set: Average loss: 0.0092, Accuracy: 1444/10000 (14%)
#
# Testing on task:  3
# Test set: Average loss: 0.0089, Accuracy: 1803/10000 (18%)
#
# Testing on task:  4
# Test set: Average loss: 0.0089, Accuracy: 1773/10000 (18%)
#
# Testing on task:  5
# Test set: Average loss: 0.0075, Accuracy: 3496/10000 (35%)
#
# Testing on task:  6
# Test set: Average loss: 0.0063, Accuracy: 5170/10000 (52%)
#
# Testing on task:  7
# Test set: Average loss: 0.0025, Accuracy: 8201/10000 (82%)
#
# Testing on task:  8
# Test set: Average loss: 0.0103, Accuracy: 1025/10000 (10%)
#
# Testing on task:  9
# Test set: Average loss: 0.0095, Accuracy: 1156/10000 (12%)
#
# Avg acc:  28.241000000000003
# Training on task:  8
# Train Epoch: 1 	Loss: 1.323632
# Train Epoch: 2 	Loss: 1.175229
# Testing on task:  0
# Test set: Average loss: 0.0086, Accuracy: 2297/10000 (23%)
#
# Testing on task:  1
# Test set: Average loss: 0.0088, Accuracy: 1781/10000 (18%)
#
# Testing on task:  2
# Test set: Average loss: 0.0089, Accuracy: 1662/10000 (17%)
#
# Testing on task:  3
# Test set: Average loss: 0.0086, Accuracy: 2320/10000 (23%)
#
# Testing on task:  4
# Test set: Average loss: 0.0088, Accuracy: 1817/10000 (18%)
#
# Testing on task:  5
# Test set: Average loss: 0.0075, Accuracy: 3493/10000 (35%)
#
# Testing on task:  6
# Test set: Average loss: 0.0080, Accuracy: 3179/10000 (32%)
#
# Testing on task:  7
# Test set: Average loss: 0.0062, Accuracy: 4796/10000 (48%)
#
# Testing on task:  8
# Test set: Average loss: 0.0024, Accuracy: 8277/10000 (83%)
#
# Testing on task:  9
# Test set: Average loss: 0.0101, Accuracy: 822/10000 (8%)
#
# Avg acc:  30.444000000000006
# Training on task:  9
# Train Epoch: 1 	Loss: 1.447034
# Train Epoch: 2 	Loss: 1.239867
# Testing on task:  0
# Test set: Average loss: 0.0086, Accuracy: 2123/10000 (21%)
#
# Testing on task:  1
# Test set: Average loss: 0.0085, Accuracy: 2084/10000 (21%)
#
# Testing on task:  2
# Test set: Average loss: 0.0088, Accuracy: 1801/10000 (18%)
#
# Testing on task:  3
# Test set: Average loss: 0.0086, Accuracy: 1887/10000 (19%)
#
# Testing on task:  4
# Test set: Average loss: 0.0089, Accuracy: 1787/10000 (18%)
#
# Testing on task:  5
# Test set: Average loss: 0.0081, Accuracy: 2749/10000 (27%)
#
# Testing on task:  6
# Test set: Average loss: 0.0081, Accuracy: 2525/10000 (25%)
#
# Testing on task:  7
# Test set: Average loss: 0.0078, Accuracy: 3032/10000 (30%)
#
# Testing on task:  8
# Test set: Average loss: 0.0056, Accuracy: 5412/10000 (54%)
#
# Testing on task:  9
# Test set: Average loss: 0.0027, Accuracy: 8077/10000 (81%)
#
# Avg acc:  31.476999999999997

# %% [markdown]
# ### Actividad Práctica 2
#
# *  Gráfique cómo evoluciona el accuracy promedio con diferentes valores de *num_past_elem*. Explique los resultados.
# *  Explique el trade-off que existe entre el accuracy logrado y la memoria utilizada por los datos anteriores. Puede utilizar [getsizeof](https://docs.python.org/2/library/sys.html#sys.getsizeof)
# *  Porque es necesario aplicar la función *shuffle* antes de entrenar con los datos de la tarea actual y la pasada.

# %%
# Respuestas #

# %% [markdown]
# ## Elastic Weights Consolidation (EWC) Strategy
#
# Como vimos en clases, EWC es una estrategia que se propuso en: "[Overcoming catastrophic forgetting in neural networks](https://arxiv.org/abs/1612.00796)".
#
# Este método busca penalizar la modificación de ciertos pesos relevantes para tareas anteriores y que al modificarlos pueden provocar una reducción del rendimiento de estas tareas. Los pesos importantes se encuentran mediante la información de la matriz de Fisher, que se puede aproximar con el valor del gradiente al cuadrado.
#
# Este método tiene la gran ventaja de que no necesita guardar elementos de tareas anteriores, lo cual lo hace eficiente con el uso de la memoria.

# %%
fisher_dict = {}
optpar_dict = {}
ewc_lambda =0.8

# %%
model = Net().to(device)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %% [markdown]
# Necesitamos una función que nos entregue la importancia de cada peso para cada una de las tareas, ya que como podemos ver en la siguiente ecuación:
#
# > $L_{EWC} = \sum_i \frac{\lambda}{2} F_i (\theta_i - \theta_{A,i}^*) $
#
# Cada peso tiene un valor asociado, si este valor es alto implica que es un peso importante y cambiarlo mucho aumentaría el valor de la función de pérdida.
#
# Tal como hemos dicho, el valor de $F_i$ se puede aproximar con el gradiente:
#
# > $ F_i =  g_i^2 $

# %%
def on_task_update(task_id, x_mem, t_mem, bs=256, fisher_clip=1e3):
  model.eval()  # desactiva dropout para medir Fisher
  # inicializa acumuladores en GPU
  fisher = {name: torch.zeros_like(p, device="cuda")
            for name, p in model.named_parameters() if p.requires_grad}
  N = 0  # nº de muestras acumuladas

  for start in range(0, len(t_mem), bs):
      end = min(start + bs, len(t_mem))
      x = torch.from_numpy(x_mem[start:end]).float().to(device)
      y = torch.from_numpy(t_mem[start:end]).long().to(device)

      model.zero_grad(set_to_none=True)
      out = model(x)
      loss = F.cross_entropy(out, y, reduction="mean")
      loss.backward()

      bsz = x.size(0)
      for name, p in model.named_parameters():
          if p.grad is None or not p.requires_grad:
              continue
          g = p.grad.detach()
          # acumula g^2 ponderado por tamaño de batch
          fisher[name] += (g * g).to("cuda") * bsz
      N += bsz

  # promedio sobre el nº total de muestras
  eps = 1e-12
  for name in fisher:
      f = fisher[name] / max(1, N)           # El valor esperado de [g^2]
      fisher[name] = f

  # guarda parámetros óptimos y Fisher en CPU
  fisher_dict[task_id] = {name: fisher[name] for name in fisher}
  optpar_dict[task_id] = {name: p.detach().clone()
                          for name, p in model.named_parameters() if p.requires_grad}

  model.train()

# %% [markdown]
# Como es una estrategia de regularización, necesitamos cambiar nuestra función de pérdida para agregar el el valor descrito anteriormente:
#
# > $ L = L_T + L_{EWC} $

# %%
def train_ewc(model, device, task_id, x_train, t_train, optimizer, epoch):
    model.train()

    for start in range(0, len(t_train)-1, 256):
        end = start + 256
        x, y = torch.from_numpy(x_train[start:end]), torch.from_numpy(t_train[start:end]).long()
        x, y = x.to(device), y.to(device)

        optimizer.zero_grad()

        output = model(x)
        loss = F.cross_entropy(output, y)

        ### EWC! :-)
        for task in range(task_id):
            for name, param in model.named_parameters():
                fisher = fisher_dict[task][name]
                optpar = optpar_dict[task][name]
                loss += (fisher * (optpar - param).pow(2)).sum() * ewc_lambda

        loss.backward()
        optimizer.step()
        #print(loss.item())
    print('Train Epoch: {} \tLoss: {:.6f}'.format(epoch, loss.item()))

# %% [markdown]
# Con el método y las funciones ya definidas, solo nos queda entrenar nuestro modelo.

# %%
ewc_accs = []
for id, task in enumerate(tasks):
    avg_acc = 0
    print("Training on task: ", id)

    (x_train, y_train), _ = task

    for epoch in range(1, 3):
        train_ewc(model, device, id, x_train, y_train, optimizer, epoch)
    on_task_update(id, x_train, y_train)

    for id_test, task in enumerate(tasks):
        print("Testing on task: ", id_test)
        _, (x_test, y_test) = task
        acc = test(model, device, x_test, y_test)
        avg_acc = avg_acc + acc

    print("Avg acc: ", avg_acc / len(tasks))
    ewc_accs.append(avg_acc / len(tasks))
# Out:
# Training on task:  0
# Train Epoch: 1 	Loss: 2.070391
# Train Epoch: 2 	Loss: 1.189935
# Testing on task:  0
# Test set: Average loss: 0.0029, Accuracy: 7804/10000 (78%)
#
# Testing on task:  1
# Test set: Average loss: 0.0106, Accuracy: 1039/10000 (10%)
#
# Testing on task:  2
# Test set: Average loss: 0.0109, Accuracy: 1280/10000 (13%)
#
# Testing on task:  3
# Test set: Average loss: 0.0121, Accuracy: 1023/10000 (10%)
#
# Testing on task:  4
# Test set: Average loss: 0.0116, Accuracy: 1298/10000 (13%)
#
# Testing on task:  5
# Test set: Average loss: 0.0122, Accuracy: 835/10000 (8%)
#
# Testing on task:  6
# Test set: Average loss: 0.0110, Accuracy: 1007/10000 (10%)
#
# Testing on task:  7
# Test set: Average loss: 0.0113, Accuracy: 1122/10000 (11%)
#
# Testing on task:  8
# Test set: Average loss: 0.0127, Accuracy: 696/10000 (7%)
#
# Testing on task:  9
# Test set: Average loss: 0.0119, Accuracy: 905/10000 (9%)
#
# Avg acc:  17.009000000000004
# Training on task:  1
# Train Epoch: 1 	Loss: 1.261654
# Train Epoch: 2 	Loss: 0.809635
# Testing on task:  0
# Test set: Average loss: 0.0064, Accuracy: 4694/10000 (47%)
#
# Testing on task:  1
# Test set: Average loss: 0.0018, Accuracy: 8619/10000 (86%)
#
# Testing on task:  2
# Test set: Average loss: 0.0116, Accuracy: 1348/10000 (13%)
#
# Testing on task:  3
# Test set: Average loss: 0.0137, Accuracy: 986/10000 (10%)
#
# Testing on task:  4
# Test set: Average loss: 0.0131, Accuracy: 1101/10000 (11%)
#
# Testing on task:  5
# Test set: Average loss: 0.0126, Accuracy: 1622/10000 (16%)
#
# Testing on task:  6
# Test set: Average loss: 0.0138, Accuracy: 1177/10000 (12%)
#
# Testing on task:  7
# Test set: Average loss: 0.0139, Accuracy: 1092/10000 (11%)
#
# Testing on task:  8
# Test set: Average loss: 0.0150, Accuracy: 750/10000 (8%)
#
# Testing on task:  9
# Test set: Average loss: 0.0123, Accuracy: 1363/10000 (14%)
#
# Avg acc:  22.751999999999995
# Training on task:  2
# Train Epoch: 1 	Loss: 1.430456
# Train Epoch: 2 	Loss: 0.888578
# Testing on task:  0
# Test set: Average loss: 0.0088, Accuracy: 2255/10000 (23%)
#
# Testing on task:  1
# Test set: Average loss: 0.0077, Accuracy: 3134/10000 (31%)
#
# Testing on task:  2
# Test set: Average loss: 0.0020, Accuracy: 8438/10000 (84%)
#
# Testing on task:  3
# Test set: Average loss: 0.0113, Accuracy: 981/10000 (10%)
#
# Testing on task:  4
# Test set: Average loss: 0.0124, Accuracy: 1340/10000 (13%)
#
# Testing on task:  5
# Test set: Average loss: 0.0138, Accuracy: 787/10000 (8%)
#
# Testing on task:  6
# Test set: Average loss: 0.0118, Accuracy: 1006/10000 (10%)
#
# Testing on task:  7
# Test set: Average loss: 0.0128, Accuracy: 1152/10000 (12%)
#
# Testing on task:  8
# Test set: Average loss: 0.0119, Accuracy: 1204/10000 (12%)
#
# Testing on task:  9
# Test set: Average loss: 0.0116, Accuracy: 1302/10000 (13%)
#
# Avg acc:  21.599
# Training on task:  3
# Train Epoch: 1 	Loss: 1.537990
# Train Epoch: 2 	Loss: 1.364626
# Testing on task:  0
# Test set: Average loss: 0.0103, Accuracy: 1666/10000 (17%)
#
# Testing on task:  1
# Test set: Average loss: 0.0119, Accuracy: 994/10000 (10%)
#
# Testing on task:  2
# Test set: Average loss: 0.0098, Accuracy: 1710/10000 (17%)
#
# Testing on task:  3
# Test set: Average loss: 0.0028, Accuracy: 7888/10000 (79%)
#
# Testing on task:  4
# Test set: Average loss: 0.0122, Accuracy: 802/10000 (8%)
#
# Testing on task:  5
# Test set: Average loss: 0.0116, Accuracy: 831/10000 (8%)
#
# Testing on task:  6
# Test set: Average loss: 0.0114, Accuracy: 896/10000 (9%)
#
# Testing on task:  7
# Test set: Average loss: 0.0132, Accuracy: 727/10000 (7%)
#
# Testing on task:  8
# Test set: Average loss: 0.0120, Accuracy: 603/10000 (6%)
#
# Testing on task:  9
# Test set: Average loss: 0.0128, Accuracy: 511/10000 (5%)
#
# Avg acc:  16.628000000000004
# Training on task:  4
# Train Epoch: 1 	Loss: 2.118953
# Train Epoch: 2 	Loss: 1.755412
# Testing on task:  0
# Test set: Average loss: 0.0116, Accuracy: 697/10000 (7%)
#
# Testing on task:  1
# Test set: Average loss: 0.0097, Accuracy: 1235/10000 (12%)
#
# Testing on task:  2
# Test set: Average loss: 0.0095, Accuracy: 1515/10000 (15%)
#
# Testing on task:  3
# Test set: Average loss: 0.0100, Accuracy: 1081/10000 (11%)
#
# Testing on task:  4
# Test set: Average loss: 0.0043, Accuracy: 7021/10000 (70%)
#
# Testing on task:  5
# Test set: Average loss: 0.0109, Accuracy: 622/10000 (6%)
#
# Testing on task:  6
# Test set: Average loss: 0.0097, Accuracy: 1491/10000 (15%)
#
# Testing on task:  7
# Test set: Average loss: 0.0099, Accuracy: 1228/10000 (12%)
#
# Testing on task:  8
# Test set: Average loss: 0.0113, Accuracy: 483/10000 (5%)
#
# Testing on task:  9
# Test set: Average loss: 0.0105, Accuracy: 901/10000 (9%)
#
# Avg acc:  16.274
# Training on task:  5
# Train Epoch: 1 	Loss: 2.318286
# Train Epoch: 2 	Loss: 2.319588
# Testing on task:  0
# Test set: Average loss: 0.0092, Accuracy: 1136/10000 (11%)
#
# Testing on task:  1
# Test set: Average loss: 0.0092, Accuracy: 1141/10000 (11%)
#
# Testing on task:  2
# Test set: Average loss: 0.0092, Accuracy: 1135/10000 (11%)
#
# Testing on task:  3
# Test set: Average loss: 0.0092, Accuracy: 1135/10000 (11%)
#
# Testing on task:  4
# Test set: Average loss: 0.0092, Accuracy: 1135/10000 (11%)
#
# Testing on task:  5
# Test set: Average loss: 0.0092, Accuracy: 1135/10000 (11%)
#
# Testing on task:  6
# Test set: Average loss: 0.0092, Accuracy: 1132/10000 (11%)
#
# Testing on task:  7
# Test set: Average loss: 0.0092, Accuracy: 1136/10000 (11%)
#
# Testing on task:  8
# Test set: Average loss: 0.0092, Accuracy: 1135/10000 (11%)
#
# Testing on task:  9
# Test set: Average loss: 0.0092, Accuracy: 1134/10000 (11%)
#
# Avg acc:  11.354000000000001
# Training on task:  6
# Train Epoch: 1 	Loss: 2.320554
# Train Epoch: 2 	Loss: 1.817722
# Testing on task:  0
# Test set: Average loss: 0.0092, Accuracy: 1463/10000 (15%)
#
# Testing on task:  1
# Test set: Average loss: 0.0084, Accuracy: 2429/10000 (24%)
#
# Testing on task:  2
# Test set: Average loss: 0.0105, Accuracy: 938/10000 (9%)
#
# Testing on task:  3
# Test set: Average loss: 0.0101, Accuracy: 1161/10000 (12%)
#
# Testing on task:  4
# Test set: Average loss: 0.0104, Accuracy: 1168/10000 (12%)
#
# Testing on task:  5
# Test set: Average loss: 0.0101, Accuracy: 1150/10000 (12%)
#
# Testing on task:  6
# Test set: Average loss: 0.0051, Accuracy: 6697/10000 (67%)
#
# Testing on task:  7
# Test set: Average loss: 0.0099, Accuracy: 1358/10000 (14%)
#
# Testing on task:  8
# Test set: Average loss: 0.0100, Accuracy: 1029/10000 (10%)
#
# Testing on task:  9
# Test set: Average loss: 0.0098, Accuracy: 1120/10000 (11%)
#
# Avg acc:  18.512999999999998
# Training on task:  7
# Train Epoch: 1 	Loss: 1.986729
# Train Epoch: 2 	Loss: 1.822471
# Testing on task:  0
# Test set: Average loss: 0.0114, Accuracy: 937/10000 (9%)
#
# Testing on task:  1
# Test set: Average loss: 0.0098, Accuracy: 1240/10000 (12%)
#
# Testing on task:  2
# Test set: Average loss: 0.0095, Accuracy: 1218/10000 (12%)
#
# Testing on task:  3
# Test set: Average loss: 0.0108, Accuracy: 833/10000 (8%)
#
# Testing on task:  4
# Test set: Average loss: 0.0104, Accuracy: 1185/10000 (12%)
#
# Testing on task:  5
# Test set: Average loss: 0.0115, Accuracy: 662/10000 (7%)
#
# Testing on task:  6
# Test set: Average loss: 0.0095, Accuracy: 1475/10000 (15%)
#
# Testing on task:  7
# Test set: Average loss: 0.0043, Accuracy: 7250/10000 (72%)
#
# Testing on task:  8
# Test set: Average loss: 0.0109, Accuracy: 683/10000 (7%)
#
# Testing on task:  9
# Test set: Average loss: 0.0103, Accuracy: 1274/10000 (13%)
#
# Avg acc:  16.757
# Training on task:  8
# Train Epoch: 1 	Loss: 2.325268
# Train Epoch: 2 	Loss: 2.319759
# Testing on task:  0
# Test set: Average loss: 0.0092, Accuracy: 1136/10000 (11%)
#
# Testing on task:  1
# Test set: Average loss: 0.0092, Accuracy: 1142/10000 (11%)
#
# Testing on task:  2
# Test set: Average loss: 0.0092, Accuracy: 1135/10000 (11%)
#
# Testing on task:  3
# Test set: Average loss: 0.0092, Accuracy: 1135/10000 (11%)
#
# Testing on task:  4
# Test set: Average loss: 0.0092, Accuracy: 1135/10000 (11%)
#
# Testing on task:  5
# Test set: Average loss: 0.0092, Accuracy: 1135/10000 (11%)
#
# Testing on task:  6
# Test set: Average loss: 0.0092, Accuracy: 1135/10000 (11%)
#
# Testing on task:  7
# Test set: Average loss: 0.0092, Accuracy: 1135/10000 (11%)
#
# Testing on task:  8
# Test set: Average loss: 0.0092, Accuracy: 1135/10000 (11%)
#
# Testing on task:  9
# Test set: Average loss: 0.0092, Accuracy: 1135/10000 (11%)
#
# Avg acc:  11.357999999999999
# Training on task:  9
# Train Epoch: 1 	Loss: 2.319781
# Train Epoch: 2 	Loss: 1.748123
# Testing on task:  0
# Test set: Average loss: 0.0102, Accuracy: 1005/10000 (10%)
#
# Testing on task:  1
# Test set: Average loss: 0.0094, Accuracy: 1347/10000 (13%)
#
# Testing on task:  2
# Test set: Average loss: 0.0086, Accuracy: 2206/10000 (22%)
#
# Testing on task:  3
# Test set: Average loss: 0.0097, Accuracy: 1307/10000 (13%)
#
# Testing on task:  4
# Test set: Average loss: 0.0108, Accuracy: 669/10000 (7%)
#
# Testing on task:  5
# Test set: Average loss: 0.0106, Accuracy: 588/10000 (6%)
#
# Testing on task:  6
# Test set: Average loss: 0.0097, Accuracy: 1244/10000 (12%)
#
# Testing on task:  7
# Test set: Average loss: 0.0099, Accuracy: 1048/10000 (10%)
#
# Testing on task:  8
# Test set: Average loss: 0.0098, Accuracy: 1169/10000 (12%)
#
# Testing on task:  9
# Test set: Average loss: 0.0049, Accuracy: 6409/10000 (64%)
#
# Avg acc:  16.992

# %% [markdown]
# ### Actividad Práctica 3
#
# * Graficar el accuracy promedio con diferentes valores de lambda. Explique los resultados.
# * Compare la memoria extra utilizada por la estrategia de Rehersal (con 500 elementos por tarea) con lo utilizado por EWC. Explique el procedimiento y resultados, comparandolo con el mejor lambda obtenido en el punto anterior.

# %%
# Resultados #

# %% [markdown]
# ## Comparación de Resultados
#
# Para una mejor comparación de los métodos que vimos hoy en el laboratorio, vamos a graficar los resultados del accuracy promedio obtenido por los diferentes métodos, después de entrenar cada una de las tareas.
#
# Con este gráfico estamos diciendo que no solo es importante no olvidar, sino que el poder aprender pesos que puedan servir a tareas futuras también es relevante.

# %%
plt.plot([i for i in range(1,num_tasks+1)], naive_accs, '-o', label="Naive")
plt.plot([i for i in range(1,num_tasks+1)], rehe_accs, '-o', label="Rehearsal")
plt.plot([i for i in range(1,num_tasks+1)], ewc_accs, '-o', label="EWC")
plt.xlabel('Tasks Encountered', fontsize=14)
plt.ylabel('Average Accuracy', fontsize=14)
plt.title('CL Strategies Comparison on MNIST', fontsize=14);
plt.xticks([i for i in range(1,num_tasks+1)])
plt.legend(prop={'size': 16});
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_26858/2540041768.py in <cell line: 0>()
# ----> 1 plt.plot([i for i in range(1,num_tasks+1)], naive_accs, '-o', label="Naive")
#       2 plt.plot([i for i in range(1,num_tasks+1)], rehe_accs, '-o', label="Rehearsal")
#       3 plt.plot([i for i in range(1,num_tasks+1)], ewc_accs, '-o', label="EWC")
#       4 plt.xlabel('Tasks Encountered', fontsize=14)
#       5 plt.ylabel('Average Accuracy', fontsize=14)
#
# /usr/local/lib/python3.13/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3827     **kwargs,
#    3828 ) -> list[Line2D]:
# -> 3829     return gca().plot(
#    3830         *args,
#    3831         scalex=scalex,
#
# /usr/local/lib/python3.13/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1775         """
#    1776         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777         lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778         for line in lines:
#    1779             self.add_line(line)
#
# /usr/local/lib/python3.13/dist-packages/matplotlib/axes/_base.py in __call__(self, axes, data, return_kwargs, *args, **kwargs)
#     295                 this += args[0],
#     296                 args = args[1:]
# --> 297             yield from self._plot_args(
#     298                 axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     299                 return_kwargs=return_kwargs
#
# /usr/local/lib/python3.13/dist-packages/matplotlib/axes/_base.py in _plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     492
#     493         if x.shape[0] != y.shape[0]:
# --> 494             raise ValueError(f"x and y must have same first dimension, but "
#     495                              f"have shapes {x.shape} and {y.shape}")
#     496         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (10,) and (4,)

# %% [markdown]
# ### Actividad Práctica 4
#
# *  Explique y haga una comparación entre los diferentes métodos mostrados en el gráfico anterior.
# *  De ejemplos donde es mejor un método u otro. Explique sus razones.

# %% [markdown]
# # Material Extra
#
# *   Sequoia ([Github](https://github.com/lebrice/Sequoia))
# *   Avalanche ([Pagina](https://avalanche.continualai.org/))
# *   Curso Continual AI ([YouTube](https://www.youtube.com/watch?v=z9DDg2CJjeE&list=PLm6QXeaB-XkBfM5RgQP6wCR7Jegdg51Px&ab_channel=ContinualAI))
